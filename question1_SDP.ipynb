# %% [markdown]
# Guignard Quentin, Stone Tomas, Hanus Maxime

# %% [markdown]
# # Question 1 : Explication de type (1-1) pour la Comparaison x > y

# %% [markdown]
# ## Formulation Mathématique
#
# ### 1. Données et Paramètres
# - **x, y** : vecteurs de notes des deux candidats pour chaque cours i
# - **w** : vecteur des poids de chaque cours
# - **contributions(i)** = w[i] × (x[i] - y[i]) : contribution du cours i à la somme pondérée
#
# ### 2. Ensembles
# - **pros(x,y)** : ensemble des cours i où x[i] > y[i] (contributions > 0)
# - **cons(x,y)** : ensemble des cours i où x[i] < y[i] (contributions < 0)
# - **neutral(x,y)** : ensemble des cours i où x[i] = y[i] (contributions = 0)
#
# ### 3. Formulation du PL
#
# **Variables de décision:**
# - Pour chaque paire (P, C) où P \in pros(x,y) et C \in cons(x,y) :
#   - $x_{P,C} \in {0, 1}$ : égal à 1 si la paire (P, C) est sélectionnée comme trade-off
#
# **Contraintes:**
# 1. Chaque cours $C \in \text{cons}(x,y)$ doit être appairé exactement une fois :
#    $$\sum_{P \in \text{pros}(x,y)} x_{P,C} = 1 \quad \forall C \in \text{cons}(x,y)$$
#
# 2. Chaque cours $P \in \text{pros}(x,y)$ peut être appairé au plus une fois :
#    $$\sum_{C \in \text{cons}(x,y)} x_{P,C} \leq 1 \quad \forall P \in \text{pros}(x,y)$$
#
# 3. Chaque trade-off sélectionné doit être valide (contribution(P) + contribution(C) > 0) :
#    $$(\text{contribution}(P) + \text{contribution}(C)) \cdot x_{P,C} > 0$$
#
#    Ou de façon linéaire (si toutes les paires positives) :
#    $$\text{contribution}(P) + \text{contribution}(C) > 0 \quad \text{pour chaque paire sélectionnée}$$
#
# **Objectif:**
# - Minimiser le nombre de trade-offs : $\min \sum_{P,C} x_{P,C}$
# - Ou maximiser pour chercher une explication quelconque : $\max \sum_{P,C} x_{P,C}$
#
# **Certificat de non-existence:**
# Si le PL est infaisable (aucune solution), il n'existe pas d'explication (1-1).

# %%
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import pandas as pd 

# Données
courses = ['Anatomie', 'Biologie', 'Chirurgie', 'Diagnostic', 'Epidemiologie', 'Forensic', 'Genetique']
x_notes = np.array([85, 81, 71, 69, 75, 81, 88])
y_notes = np.array([81, 81, 75, 63, 67, 88, 95])
z_notes = np.array([74, 89, 74, 81, 68, 84, 79])
t_notes = np.array([74, 71, 84, 91, 77, 76, 73])
u_notes = np.array([72, 75, 66, 85, 88, 66, 93])
v_notes = np.array([71, 73, 63, 92, 76, 79, 93])
w_notes = np.array([79, 69, 78, 76, 67, 84, 79])
w_prime_notes = np.array([57, 76, 81, 76, 82, 86, 77])
weights = np.array([8, 7, 7, 6, 6, 5, 6])

# %%
def find_explanation_1_1(x_values, y_values, weights, features, candidate_x='X', candidate_y='Y'):
    """
    Trouve une explication (1-1) minimale pour x > y
    En (1-1), chaque pro couvre exactement un cons.
    Retourne: (status, explanation)
    """

    # Contributions pondérées
    contributions = weights * (x_values - y_values)
    pros = [i for i in range(len(features)) if contributions[i] > 0]
    cons = [i for i in range(len(features)) if contributions[i] < 0]
    neutral = [i for i in range(len(features)) if contributions[i] == 0]

    print(f'\n=== Analyse {candidate_x} > {candidate_y} ===')
    print(f'pros({candidate_x},{candidate_y}):  ', [features[i] for i in pros])
    print(f'cons({candidate_x},{candidate_y}):  ', [features[i] for i in cons])
    print(f'Contributions: {contributions}')

    if not cons:
        print(f'{candidate_x} domine {candidate_y} sur tous les critères.')
        return 'TRIVIAL', []
    
    if not pros:
        print(f'{candidate_y} domine {candidate_x} sur tous les critères.')
        return 'IMPOSSIBLE', []

    # Trade-offs (1-1) valides: contribution(P)+contribution(C) > 0
    valid_tradeoffs = []
    for p in pros:
        for c in cons:
            s = contributions[p] + contributions[c]
            if s > 0:
                valid_tradeoffs.append((p, c, s))

    print(f'trade-offs valides({candidate_x},{candidate_y}):', [(features[p], features[c], s) for p, c, s in valid_tradeoffs])
        
    # Résolution PL pour une explication (1-1) minimale
    m = gp.Model('explication_1_1')
    x_vars = {}
    for p, c, _ in valid_tradeoffs:
        x_vars[(p,c)] = m.addVar(vtype=GRB.BINARY, name=f'x_{p}_{c}')
    m.update()

    # Chaque cons est couvert exactement une fois
    for c in cons:
        pairs = [(p, cc) for (p, cc, _) in valid_tradeoffs if cc == c]
        m.addConstr(gp.quicksum(x_vars[(p, cc)] for (p, cc) in pairs) == 1)

    # Chaque pro est utilisé au plus une fois
    for p in pros:
        pairs = [(pp, c) for (pp, c, _) in valid_tradeoffs if pp == p]
        m.addConstr(gp.quicksum(x_vars[(pp, c)] for (pp, c) in pairs) <= 1)

    # Objectif: minimiser le nombre de paires
    m.setObjective(gp.quicksum(x_vars.values()), GRB.MINIMIZE)
    m.params.outputflag = 0
    m.optimize()

    if m.status == GRB.OPTIMAL:
        print('\nExplication (1-1) trouvée de longueur', int(m.objVal))
        chosen = []
        for (p, c), var in x_vars.items():
            if var.X > 0.5:
                chosen.append((p, c))
                pc = contributions[p]
                cc = contributions[c]
                print(f"Trade-off : {features[p]} vs. {features[c]}")
                print(f' Contributions : {pc} + ({cc}) = {pc+cc}')
        return 'OPTIMAL', chosen
    else:
        print('Pas de solution (certificat de non-existence).')
        return 'INFEASIBLE', []

# %%
result_xy, expl_xy = find_explanation_1_1(x_notes, y_notes, weights, courses, 'x', 'y')
# Out:
# === Analyse x > y ===
# pros(x,y):   ['Anatomie', 'Diagnostic', 'Epidemiologie']
# cons(x,y):   ['Chirurgie', 'Forensic', 'Genetique']
# Contributions: [ 32   0 -28  36  48 -35 -42]
# trade-offs valides(x,y): [('Anatomie', 'Chirurgie', np.int64(4)), ('Diagnostic', 'Chirurgie', np.int64(8)), ('Diagnostic', 'Forensic', np.int64(1)), ('Epidemiologie', 'Chirurgie', np.int64(20)), ('Epidemiologie', 'Forensic', np.int64(13)), ('Epidemiologie', 'Genetique', np.int64(6))]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : Anatomie vs. Chirurgie
#  Contributions : 32 + (-28) = 4
# Trade-off : Diagnostic vs. Forensic
#  Contributions : 36 + (-35) = 1
# Trade-off : Epidemiologie vs. Genetique
#  Contributions : 48 + (-42) = 6

# %% [markdown]
# # Question 2 : Explication de type (1-m) pour la Comparaison x > y

# %% [markdown]
# ## Formulation Mathématique

# %% [markdown]
# ### 1. Définition d'un Trade-off (1-m)
# Un trade-off (1-m) est une paire (P, {C₁, ..., Cₘ}) où :
# - P $\in$ pros(x,y) : un cours où x fait mieux que y
# - {C₁, ..., Cₘ} $\subset$ cons(x,y) : m cours où y fait mieux que x
# - La somme des contributions est positive : contribution(P) + Σⱼ contribution(Cⱼ) > 0
#
# ### 2. Explication (1-m)
# Une explication (1-m) de x > y est un ensemble de trade-offs (1-m) disjoints qui couvrent tous les cons(x,y).
#
# ### 3. Formulation du Programme Linéaire
#
# **Variables de décision:**
# - Pour chaque P $\in$ pros(x,y) et chaque C \in cons(x,y) :
#   - $x_{P,C} \in \{0, 1\}$ : égal à 1 si le cours C est associé au cours P dans un trade-off
#
# **Contraintes:**
# 1. Chaque cours $C \in \text{cons}(x,y)$ doit être appairé exactement une fois :
#    $$\sum_{P \in \text{pros}(x,y)} x_{P,C} = 1 \quad \forall C \in \text{cons}(x,y)$$
#
# 2. Pour chaque cours $P \in \text{pros}(x,y)$, si P est utilisé, son trade-off doit être valide :
#    $$\text{contribution}(P) + \sum_{C \in \text{cons}(x,y)} \text{contribution}(C) \cdot x_{P,C} > 0$$
#
#    Version linéarisée avec $y_P \in \{0,1\}$ (indicateur si P est utilisé) :
#    $$\text{contribution}(P) \cdot y_P + \sum_{C \in \text{cons}(x,y)} \text{contribution}(C) \cdot x_{P,C} \geq \epsilon \cdot y_P$$
#
#    où $\epsilon > 0$ est une petite constante (e.g., 0.001).
#
# 3. Lien entre $x_{P,C}$ et $y_P$ :
#    $$x_{P,C} \leq y_P \quad \forall P \in \text{pros}(x,y), C \in \text{cons}(x,y)$$
#    $$y_P \leq \sum_{C \in \text{cons}(x,y)} x_{P,C} \quad \forall P \in \text{pros}(x,y)$$
#
# **Objectif:**
# - Minimiser le nombre de trade-offs : $\min \sum_{P \in \text{pros}(x,y)} y_P$
#
# **Certificat de non-existence:**
# Si le PL est infaisable, il n'existe pas d'explication (1-m).

# %%
# Implémentation du PL pour explication (1-m)
def find_explanation_1_m(x_values, y_values, weights, features, candidate_x='X', candidate_y='Y'):
    """
    Trouve une explication (1-m) minimale pour x > y
    Retourne: (status, explanation) où status est 'OPTIMAL' ou 'INFEASIBLE'
    """
    # Contributions pondérées
    contributions = weights * (x_values - y_values)
    pros = [i for i in range(len(features)) if contributions[i] > 0]
    cons = [i for i in range(len(features)) if contributions[i] < 0]
    
    print(f'\n=== Analyse {candidate_x} > {candidate_y} ===')
    print(f'pros({candidate_x},{candidate_y}):  ', [features[i] for i in pros])
    print(f'cons({candidate_x},{candidate_y}):  ', [features[i] for i in cons])
    print(f'Contributions: {contributions}')
    
    if not cons:
        print(f'{candidate_x} domine {candidate_y} sur tous les critères.')
        return 'TRIVIAL', []
    
    if not pros:
        print(f'{candidate_y} domine {candidate_x} sur tous les critères.')
        return 'IMPOSSIBLE', []
    
    # Modèle PL
    m = gp.Model('explication_1_m')
    m.params.outputflag = 0
    
    # Variables: x[p,c] = 1 si C est associé à P
    x_vars = {}
    for p in pros:
        for c in cons:
            x_vars[(p,c)] = m.addVar(vtype=GRB.BINARY, name=f'x_{p}_{c}')
    
    # Variables: y[p] = 1 si P est utilisé dans un trade-off
    y_vars = {}
    for p in pros:
        y_vars[p] = m.addVar(vtype=GRB.BINARY, name=f'y_{p}')
    
    m.update()
    
    epsilon = 0.001
    
    # Contrainte 1: Chaque cons est couvert exactement une fois
    for c in cons:
        m.addConstr(gp.quicksum(x_vars[(p,c)] for p in pros) == 1, name=f'cover_cons_{c}')
    
    # Contrainte 2: Validité des trade-offs
    for p in pros:
        sum_contrib = contributions[p] * y_vars[p]
        for c in cons:
            sum_contrib += contributions[c] * x_vars[(p,c)]
        m.addConstr(sum_contrib >= epsilon * y_vars[p], name=f'valid_tradeoff_{p}')
    
    # Contrainte 3: Lien entre x et y
    for p in pros:
        for c in cons:
            m.addConstr(x_vars[(p,c)] <= y_vars[p], name=f'link1_{p}_{c}')
        m.addConstr(y_vars[p] <= gp.quicksum(x_vars[(p,c)] for c in cons), name=f'link2_{p}')
    
    # Objectif: minimiser le nombre de trade-offs
    m.setObjective(gp.quicksum(y_vars.values()), GRB.MINIMIZE)
    m.optimize()
    
    if m.status == GRB.OPTIMAL:
        print(f'\n Explication (1-m) trouvée, longueur = {int(m.objVal)}')
        explanation = []
        for p in pros:
            if y_vars[p].X > 0.5:
                cons_in_tradeoff = [c for c in cons if x_vars[(p,c)].X > 0.5]
                contrib_p = contributions[p]
                contrib_cons = [contributions[c] for c in cons_in_tradeoff]
                total = contrib_p + sum(contrib_cons)
                explanation.append((p, cons_in_tradeoff))
                print(f'  Trade-off: ({features[p]}) vs {[features[c] for c in cons_in_tradeoff]}')
                print(f'    Contributions: {contrib_p:.1f} + {contrib_cons} = {total:.1f}')
        return 'OPTIMAL', explanation
    else:
        print(f'\nPas d\'explication (1-m) (certificat de non-existence)')
        return 'INFEASIBLE', []

# Test avec Xavier vs Yvonne
result, expl = find_explanation_1_m(x_notes, y_notes, weights, courses, 'Xavier', 'Yvonne')
# Out:
# === Analyse Xavier > Yvonne ===
# pros(Xavier,Yvonne):   ['Anatomie', 'Diagnostic', 'Epidemiologie']
# cons(Xavier,Yvonne):   ['Chirurgie', 'Forensic', 'Genetique']
# Contributions: [ 32   0 -28  36  48 -35 -42]
#
#  Explication (1-m) trouvée, longueur = 3
#   Trade-off: (Anatomie) vs ['Chirurgie']
#     Contributions: 32.0 + [np.int64(-28)] = 4.0
#   Trade-off: (Diagnostic) vs ['Forensic']
#     Contributions: 36.0 + [np.int64(-35)] = 1.0
#   Trade-off: (Epidemiologie) vs ['Genetique']
#     Contributions: 48.0 + [np.int64(-42)] = 6.0

# %% [markdown]
# ## Démonstration : Absence d'explication (1-m) pour u > v
#
# Nous allons maintenant prouver qu'il n'existe pas d'explication (1-m) pour la comparaison u > v.

# %%
# Test de l'explication (1-m) pour u > v
result_uv, expl_uv = find_explanation_1_m(u_notes, v_notes, weights, courses, 'u', 'v')
# Out:
# === Analyse u > v ===
# pros(u,v):   ['Anatomie', 'Biologie', 'Chirurgie', 'Epidemiologie']
# cons(u,v):   ['Diagnostic', 'Forensic']
# Contributions: [  8  14  21 -42  72 -65   0]
#
# Pas d'explication (1-m) (certificat de non-existence)

# %% [markdown]
# ## Explication de type (m-1) pour y > z
#
# Un trade-off (m-1) est une paire ({P₁, ..., Pₘ}, C) où :
# - {P₁, ..., Pₘ} $\subset$ pros(y,z) : m cours où y fait mieux que z
# - C \in cons(y,z) : un cours où z fait mieux que y
# - La somme des contributions est positive : Σⱼ contribution(Pⱼ) + contribution(C) > 0
#
# ### Formulation du Programme Linéaire pour (m-1)
#
# **Variables:**
# - $x_{P,C} \in \{0, 1\}$ : égal à 1 si P est associé au cons C
# - $y_C \in \{0, 1\}$ : égal à 1 si C est utilisé dans un trade-off
#
# **Contraintes:**
# 1. Chaque P \in pros(y,z) est associé à exactement un C :
#    $$\sum_{C \in \text{cons}(y,z)} x_{P,C} = 1 \quad \forall P \in \text{pros}(y,z)$$
#
# 2. Validité des trade-offs (pour chaque C utilisé) :
#    $$\sum_{P \in \text{pros}(y,z)} \text{contribution}(P) \cdot x_{P,C} + \text{contribution}(C) \cdot y_C \geq \epsilon \cdot y_C$$
#
# 3. Lien entre x et y :
#    $$x_{P,C} \leq y_C \quad \forall P, C$$
#    $$y_C \leq \sum_{P \in \text{pros}(y,z)} x_{P,C} \quad \forall C$$
#
# **Objectif:** $\min \sum_C y_C$

# %%
# Implémentation du PL pour explication (m-1)
def find_explanation_m_1(x_values, y_values, weights, courses, candidate_x='X', candidate_y='Y'):
    """
    Trouve une explication (m-1) minimale pour x > y
    En (m-1), chaque cons doit être couvert par exactement un trade-off.
    Retourne: (status, explanation)
    """
    # Contributions pondérées
    contributions = weights * (x_values - y_values)
    pros = [i for i in range(len(courses)) if contributions[i] > 0]
    cons = [i for i in range(len(courses)) if contributions[i] < 0]
    
    print(f'\n=== Analyse {candidate_x} > {candidate_y} (type m-1) ===')
    print(f'pros({candidate_x},{candidate_y}):  ', [courses[i] for i in pros], 'contributions:', [contributions[i] for i in pros])
    print(f'cons({candidate_x},{candidate_y}):  ', [courses[i] for i in cons], 'contributions:', [contributions[i] for i in cons])
    
    if not cons:
        print(f'{candidate_x} domine {candidate_y} sur tous les critères.')
        return 'TRIVIAL', []
    
    if not pros:
        print(f'{candidate_y} domine {candidate_x} sur tous les critères.')
        return 'IMPOSSIBLE', []
    
    # Modèle PL
    m = gp.Model('explication_m_1')
    m.params.outputflag = 0
    
    # Variables: x[p,c] = 1 si P est associé à C
    x_vars = {}
    for p in pros:
        for c in cons:
            x_vars[(p,c)] = m.addVar(vtype=GRB.BINARY, name=f'x_{p}_{c}')
    
    # Variables: y[c] = 1 si C est utilisé dans un trade-off (sera forcé à 1)
    y_vars = {}
    for c in cons:
        y_vars[c] = m.addVar(vtype=GRB.BINARY, name=f'y_{c}')
    
    m.update()
    
    epsilon = 0.0
    
    # Contrainte 1: Chaque cons DOIT être couvert (y_c = 1)
    for c in cons:
        m.addConstr(y_vars[c] == 1, name=f'cover_con_{c}')
    
    # Contrainte 2: Chaque pro est utilisé au plus une fois
    for p in pros:
        m.addConstr(gp.quicksum(x_vars[(p,c)] for c in cons) <= 1, name=f'pro_used_once_{p}')
    
    # Contrainte 3: Validité des trade-offs
    # Pour chaque cons, la somme des contributions (cons + ses pros associés) doit être >= 0
    for c in cons:
        sum_contrib = contributions[c] * y_vars[c]
        sum_contrib += gp.quicksum(contributions[p] * x_vars[(p,c)] for p in pros)
        m.addConstr(sum_contrib >= epsilon * y_vars[c], name=f'valid_tradeoff_{c}')
    
    # Contrainte 4: Lien entre x et y (y[c] contrôle quels x peuvent être non-zéro)
    for c in cons:
        for p in pros:
            m.addConstr(x_vars[(p,c)] <= y_vars[c], name=f'link1_{p}_{c}')
        m.addConstr(y_vars[c] <= gp.quicksum(x_vars[(p,c)] for p in pros), name=f'link2_{c}')
    
    # Objectif: minimiser le nombre total de pros utilisés (plutôt que sum(y) qui est constant)
    m.setObjective(gp.quicksum(x_vars.values()), GRB.MINIMIZE)
    m.optimize()
    
    if m.status == GRB.OPTIMAL:
        # Compter le nombre de trade-offs (= nombre de cons couverts = len(cons))
        num_tradeoffs = sum(1 for c in cons if y_vars[c].X > 0.5)
        print(f'\n Explication (m-1) trouvée, longueur = {num_tradeoffs}')
        explanation = []
        for c in cons:
            if y_vars[c].X > 0.5:
                pros_in_tradeoff = [p for p in pros if x_vars[(p,c)].X > 0.5]
                contrib_c = contributions[c]
                contrib_pros = [contributions[p] for p in pros_in_tradeoff]
                total = sum(contrib_pros) + contrib_c
                explanation.append((pros_in_tradeoff, c))
                print(f'  Trade-off: {[courses[p] for p in pros_in_tradeoff]} vs ({courses[c]})')
                print(f'    Contributions: {contrib_pros} + {contrib_c:.1f} = {total:.1f}')
        return 'OPTIMAL', explanation
    else:
        print(f'\n  Pas d\'explication (m-1) (certificat de non-existence)')
        return 'INFEASIBLE', []

# Test de l'explication (m-1) pour y > z
result_yz, expl_yz = find_explanation_m_1(y_notes, z_notes, weights, courses, 'y', 'z')
# Out:
# === Analyse y > z (type m-1) ===
# pros(y,z):   ['Anatomie', 'Chirurgie', 'Forensic', 'Genetique'] contributions: [np.int64(56), np.int64(7), np.int64(20), np.int64(96)]
# cons(y,z):   ['Biologie', 'Diagnostic', 'Epidemiologie'] contributions: [np.int64(-56), np.int64(-108), np.int64(-6)]
#
#  Explication (m-1) trouvée, longueur = 3
#   Trade-off: ['Anatomie'] vs (Biologie)
#     Contributions: [np.int64(56)] + -56.0 = 0.0
#   Trade-off: ['Forensic', 'Genetique'] vs (Diagnostic)
#     Contributions: [np.int64(20), np.int64(96)] + -108.0 = 8.0
#   Trade-off: ['Chirurgie'] vs (Epidemiologie)
#     Contributions: [np.int64(7)] + -6.0 = 1.0

# %% [markdown]
# # Question 3 : Explications Combinées (m-1) et (1-m)

# %% [markdown]
# ## Formulation Mathématique
#
# ### 1. Définitions
#
# Une **explication combinée** de x > y est un ensemble E = {(P₁^(m₁), C₁), ..., (Pₖ^(mₖ), Cₖ), (P'₁, C'₁^(n₁)), ..., (P'ₗ, C'ₗ^(nₗ))} où :
# - Les k premiers sont des trade-offs de type (m-1) : chaque (Pᵢ^(mᵢ), Cᵢ) a mᵢ pros et 1 cons
# - Les ℓ derniers sont des trade-offs de type (1-m) : chaque (P'ⱼ, C'ⱼ^(nⱼ)) a 1 pro et nⱼ cons
# - Tous les cons(x,y) sont couverts exactement une fois
# - Chaque trade-off est valide (somme des contributions > 0)
#
# ### 2. Formulation ILP Combinée
#
# **Variables:**
# - $x_{p,c} \in \{0, 1\}$ : pro p est associé au cons c dans un trade-off
# - $z_c \in \{0, 1\}$ : cons c est utilisé dans un trade-off (type m-1 si z_c=1)
# - $w_p \in \{0, 1\}$ : pro p est utilisé dans un trade-off (type 1-m si w_p=1)
# - $y_c \in \{0, 1\}$ : cons c est couvert (dans n'importe quel trade-off)
#
# **Contraintes:**
#
# 1. **Couverture des cons** (exactement une fois) :
#    $$\sum_{p \in pros} x_{p,c} = 1 \quad \forall c \in cons$$
#
# 2. **Chaque pro au plus une fois** :
#    $$\sum_{c \in cons} x_{p,c} \leq 1 \quad \forall p \in pros$$
#
# 3. **Validité des trade-offs** :
#    $$\sum_{p \in pros} \omega_p \cdot x_{p,c} + \omega_c \geq 0 \quad \forall c \in cons$$
#
# 4. **Activation des indicateurs** :
#    - Si c est couvert : $y_c = 1$
#    - Si c est en (m-1) : $z_c \leq \sum_p x_{p,c}$
#    - Si c est en (1-m) : $w_p \leq \sum_c x_{p,c}$
#
# **Objectif:**
# - Minimiser la longueur totale : $\min \sum_c y_c$
#
# ### 3. Analyse de z > t
#
# Pour z > t, nous allons montrer :
# 1. Qu'il n'existe pas d'explication (1-m) seule
# 2. Qu'il n'existe pas d'explication (m-1) seule
# 3. Qu'une explication combinée existe

# %%
# Vérification pour z > t : pas de (1-m) ni (m-1) seule
print('\n' + '='*80)
print('QUESTION 3 : Analyse de z > t')
print('='*80)

print('\n--- Test (1-m) pour z > t ---')
result_1m, expl_1m = find_explanation_1_m(z_notes, t_notes, weights, courses, 'z', 't')

print('\n--- Test (m-1) pour z > t ---')
result_m1, expl_m1 = find_explanation_m_1(z_notes, t_notes, weights, courses, 'z', 't')
# Out:
# ================================================================================
# QUESTION 3 : Analyse de z > t
# ================================================================================
#
# --- Test (1-m) pour z > t ---
#
# === Analyse z > t ===
# pros(z,t):   ['Biologie', 'Forensic', 'Genetique']
# cons(z,t):   ['Chirurgie', 'Diagnostic', 'Epidemiologie']
# Contributions: [  0 126 -70 -60 -54  40  36]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# --- Test (m-1) pour z > t ---
#
# === Analyse z > t (type m-1) ===
# pros(z,t):   ['Biologie', 'Forensic', 'Genetique'] contributions: [np.int64(126), np.int64(40), np.int64(36)]
# cons(z,t):   ['Chirurgie', 'Diagnostic', 'Epidemiologie'] contributions: [np.int64(-70), np.int64(-60), np.int64(-54)]
#
#   Pas d'explication (m-1) (certificat de non-existence)

# %%
# Implémentation du PL pour explication mixte (m-1) + (1-m)
def find_explanation_mixed(x_values, y_values, weights, courses, candidate_x='X', candidate_y='Y'):
    """
    Trouve une explication mixte combinant (m-1) et (1-m) pour x > y
    - (m-1): plusieurs pros couvrent 1 cons
    - (1-m): 1 pro couvre plusieurs cons
    Retourne: (status, explanation)
    """
    x_values = np.array(x_values, dtype=float)
    y_values = np.array(y_values, dtype=float)
    weights = np.array(weights, dtype=float)

    omega = weights * (x_values - y_values)
    pros = [i for i in range(len(courses)) if omega[i] > 0]
    cons = [i for i in range(len(courses)) if omega[i] < 0]

    print(f'\n=== Analyse {candidate_x} > {candidate_y} (type mixte) ===')
    print(f'pros({candidate_x},{candidate_y}):  ', [courses[i] for i in pros], 'contributions:', [omega[i] for i in pros])
    print(f'cons({candidate_x},{candidate_y}):  ', [courses[i] for i in cons], 'contributions:', [omega[i] for i in cons])

    if not cons:
        print(f'{candidate_x} domine {candidate_y} sur tous les critères.')
        return 'TRIVIAL', []
    if not pros:
        print(f'{candidate_y} domine {candidate_x} sur tous les critères.')
        return 'IMPOSSIBLE', []

    M = float(np.sum(np.abs(omega)) + 1.0)
    epsilon = 0.0

    m = gp.Model('explication_mixte')
    m.Params.OutputFlag = 0

    # Variables (m-1): x_pc[p,c] = 1 si pro p est associé au cons c dans un trade-off (m-1)
    x_pc = {(p,c): m.addVar(vtype=GRB.BINARY, name=f'x_{p}_{c}') for p in pros for c in cons}
    # y_c[c] = 1 si cons c est couvert par un trade-off (m-1)
    y_c = {c: m.addVar(vtype=GRB.BINARY, name=f'y_{c}') for c in cons}

    # Variables (1-m): z_pc[p,c] = 1 si cons c est associé au pro p dans un trade-off (1-m)
    z_pc = {(p,c): m.addVar(vtype=GRB.BINARY, name=f'z_{p}_{c}') for p in pros for c in cons}
    # u_p[p] = 1 si pro p est utilisé dans un trade-off (1-m)
    u_p = {p: m.addVar(vtype=GRB.BINARY, name=f'u_{p}') for p in pros}

    m.update()

    # Contrainte 1: Chaque cons couvert exactement une fois (soit par m-1 soit par 1-m)
    for c in cons:
        m.addConstr(y_c[c] + gp.quicksum(z_pc[(p,c)] for p in pros) == 1, name=f'cover_{c}')

    # Contrainte 2: Cohérence et validité des trade-offs (m-1)
    for c in cons:
        for p in pros:
            m.addConstr(x_pc[(p,c)] <= y_c[c], name=f'link_m1_{p}_{c}')
        m.addConstr(gp.quicksum(x_pc[(p,c)] for p in pros) >= y_c[c], name=f'nonempty_m1_{c}')
        m.addConstr(
            omega[c] + gp.quicksum(omega[p] * x_pc[(p,c)] for p in pros) >= epsilon - M*(1 - y_c[c]),
            name=f'valid_m1_{c}'
        )

    # Contrainte 3: Cohérence et validité des trade-offs (1-m)
    for p in pros:
        for c in cons:
            m.addConstr(z_pc[(p,c)] <= u_p[p], name=f'link_1m_{p}_{c}')
        m.addConstr(gp.quicksum(z_pc[(p,c)] for c in cons) >= u_p[p], name=f'nonempty_1m_{p}')
        m.addConstr(
            omega[p] + gp.quicksum(omega[c] * z_pc[(p,c)] for c in cons) >= epsilon - M*(1 - u_p[p]),
            name=f'valid_1m_{p}'
        )

    # Contrainte 4: Pros disjoints (utilisé au plus une fois, pas dans les deux modes)
    for p in pros:
        m.addConstr(gp.quicksum(x_pc[(p,c)] for c in cons) <= 1, name=f'pro_once_m1_{p}')
        m.addConstr(gp.quicksum(x_pc[(p,c)] for c in cons) + u_p[p] <= 1, name=f'pro_disjoint_{p}')

    # Objectif: minimiser le nombre de trade-offs
    m.setObjective(gp.quicksum(y_c[c] for c in cons) + gp.quicksum(u_p[p] for p in pros), GRB.MINIMIZE)
    m.optimize()

    if m.Status != GRB.OPTIMAL:
        print(f'\nPas d\'explication mixte (certificat de non-existence)')
        return 'INFEASIBLE', []

    # Collecter les trade-offs
    explanation = []
    
    # Trade-offs (m-1)
    for c in cons:
        if y_c[c].X > 0.5:
            P = [p for p in pros if x_pc[(p,c)].X > 0.5]
            val = float(omega[c] + sum(omega[p] for p in P))
            explanation.append(('m-1', P, [c], val))

    # Trade-offs (1-m)
    for p in pros:
        if u_p[p].X > 0.5:
            Cset = [c for c in cons if z_pc[(p,c)].X > 0.5]
            val = float(omega[p] + sum(omega[c] for c in Cset))
            explanation.append(('1-m', [p], Cset, val))

    print(f'\n Explication mixte trouvée, longueur = {len(explanation)}')
    for typ, P, Cset, val in explanation:
        if typ == 'm-1':
            print(f'  Trade-off (m-1): {[courses[i] for i in P]} vs ({courses[Cset[0]]})')
            print(f'    Contributions: {[omega[i] for i in P]} + {omega[Cset[0]]:.1f} = {val:.1f}')
        else:
            print(f'  Trade-off (1-m): ({courses[P[0]]}) vs {[courses[i] for i in Cset]}')
            print(f'    Contributions: {omega[P[0]]:.1f} + {[omega[i] for i in Cset]} = {val:.1f}')

    return 'OPTIMAL', explanation

# Test de l'explication mixte pour z > t
print('\n' + '='*80)
print('TEST EXPLICATION MIXTE pour z > t')
print('='*80)

result_mixed, expl_mixed = find_explanation_mixed(z_notes, t_notes, weights, courses, 'z', 't')
# Out:
# ================================================================================
# TEST EXPLICATION MIXTE pour z > t
# ================================================================================
#
# === Analyse z > t (type mixte) ===
# pros(z,t):   ['Biologie', 'Forensic', 'Genetique'] contributions: [np.float64(126.0), np.float64(40.0), np.float64(36.0)]
# cons(z,t):   ['Chirurgie', 'Diagnostic', 'Epidemiologie'] contributions: [np.float64(-70.0), np.float64(-60.0), np.float64(-54.0)]
#
#  Explication mixte trouvée, longueur = 2
#   Trade-off (m-1): ['Forensic', 'Genetique'] vs (Chirurgie)
#     Contributions: [np.float64(40.0), np.float64(36.0)] + -70.0 = 6.0
#   Trade-off (1-m): (Biologie) vs ['Diagnostic', 'Epidemiologie']
#     Contributions: 126.0 + [np.float64(-60.0), np.float64(-54.0)] = 12.0

# %% [markdown]
# # Question 4 : Explication de type (1-m) OU (m-1)

# %% [markdown]
# ## Formulation Mathématique
#
# On cherche une explication qui peut utiliser **soit** des trade-offs (1-m) **soit** des trade-offs (m-1) (mais pas les deux en même temps, contrairement à l'explication mixte).
#
# ### Approche
#
# 1. Tester d'abord s'il existe une explication (1-m)
# 2. Si non, tester s'il existe une explication (m-1)
# 3. Retourner la première explication trouvée, ou un certificat de non-existence
#
# ### Données des nouveaux candidats
#
# | Candidat | A | B | C | D | E | F | G |
# |----------|---|---|---|---|---|---|---|
# | a1 | 89 | 74 | 81 | 68 | 84 | 79 | 77 |
# | a2 | 71 | 84 | 91 | 79 | 78 | 73.5 | 77 |

# %%
# Définition des données pour a1 et a2
a1_notes = np.array([89, 74, 81, 68, 84, 79, 77])
a2_notes = np.array([71, 84, 91, 79, 78, 73.5, 77])

# Vérification que a1 > a2 (somme pondérée)
score_a1 = np.dot(weights, a1_notes)
score_a2 = np.dot(weights, a2_notes)
print(f'Score pondéré a1 = {score_a1}')
print(f'Score pondéré a2 = {score_a2}')
# Out:
# Score pondéré a1 = 3566
# Score pondéré a2 = 3564.5

# %%
# Application à a1 > a2
status_1_m, expl_1_m = find_explanation_1_m(a1_notes, a2_notes, weights, courses, 'a1', 'a2')
status_m_1, expl_m_1 = find_explanation_m_1(a1_notes, a2_notes, weights, courses, 'a1', 'a2')

print(f'\n{"="*80}')
print(f'RÉSULTAT FINAL')
print(f'{"="*80}')

if status_1_m == 'OPTIMAL':
    print(f'Explication trouvée de type (1-m) pour a1 > a2')
elif status_m_1 == 'OPTIMAL':
    print(f'Explication trouvée de type (m-1) pour a1 > a2')
else:
    print(f'Pas d\'explication de type (1-m) ni (m-1) pour a1 > a2')
# Out:
# === Analyse a1 > a2 ===
# pros(a1,a2):   ['Anatomie', 'Epidemiologie', 'Forensic']
# cons(a1,a2):   ['Biologie', 'Chirurgie', 'Diagnostic']
# Contributions: [144.  -70.  -70.  -66.   36.   27.5   0. ]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse a1 > a2 (type m-1) ===
# pros(a1,a2):   ['Anatomie', 'Epidemiologie', 'Forensic'] contributions: [np.float64(144.0), np.float64(36.0), np.float64(27.5)]
# cons(a1,a2):   ['Biologie', 'Chirurgie', 'Diagnostic'] contributions: [np.float64(-70.0), np.float64(-70.0), np.float64(-66.0)]
#
#   Pas d'explication (m-1) (certificat de non-existence)
#
# ================================================================================
# RÉSULTAT FINAL
# ================================================================================
# Pas d'explication de type (1-m) ni (m-1) pour a1 > a2

# %% [markdown]
# ## Analyse du Résultat
#
# **Conclusion pour a1 > a2 :**
#
# Il n'existe **pas** d'explication de type (1-m) seule, ni de type (m-1) seule pour expliquer à a2 qu'il est moins bien classé que a1.
#
# ### Pourquoi ?
#
# Analysons les contributions :
# - **pros(a1,a2)** : Anatomie (+144), Epidémiologie (+36), Forensic (+27.5) → Total = 207.5
# - **cons(a1,a2)** : Biologie (-70), Chirurgie (-70), Diagnostic (-66) → Total = -206
#
# La différence est très faible (1.5 points), ce qui rend difficile la construction de trade-offs valides.
#
# - **Pour (1-m)** : Aucun pro seul ne peut compenser plusieurs cons
#   - Anatomie (144) > Biologie + Chirurgie (140) mais il faudrait aussi couvrir Diagnostic
#
# - **Pour (m-1)** : Aucun cons seul ne peut être compensé par un sous-ensemble de pros tout en laissant assez pour les autres cons
#
# ### Solution
#
# Une explication **mixte** combinant (1-m) et (m-1) pourrait exister. Testons avec la fonction de la Question 3 :

# %%
# Test avec l'explication mixte (Question 3) pour a1 > a2
print("Test de l'explication mixte pour a1 > a2:")
result_a1a2_mixed, expl_a1a2_mixed = find_explanation_mixed(a1_notes, a2_notes, weights, courses, 'a1', 'a2')
# Out:
# Test de l'explication mixte pour a1 > a2:
#
# === Analyse a1 > a2 (type mixte) ===
# pros(a1,a2):   ['Anatomie', 'Epidemiologie', 'Forensic'] contributions: [np.float64(144.0), np.float64(36.0), np.float64(27.5)]
# cons(a1,a2):   ['Biologie', 'Chirurgie', 'Diagnostic'] contributions: [np.float64(-70.0), np.float64(-70.0), np.float64(-66.0)]
#
# Pas d'explication mixte (certificat de non-existence)

# %% [markdown]
# ## Conclusion Finale pour la Question 4
#
# ### Résultat : **Aucune explication possible**
#
# Pour la comparaison **a1 > a2**, il n'existe :
# - Pas d'explication (1-1)
# - Pas d'explication (1-m)
# - Pas d'explication (m-1)
# - Pas d'explication mixte (1-m) + (m-1)
#
# ### Explication Mathématique
#
# | Critère | a1 | a2 | Contribution pondérée |
# |---------|----|----|----------------------|
# | A (poids 8) | 89 | 71 | +144 |
# | B (poids 7) | 74 | 84 | -70 |
# | C (poids 7) | 81 | 91 | -70 |
# | D (poids 6) | 68 | 79 | -66 |
# | E (poids 6) | 84 | 78 | +36 |
# | F (poids 5) | 79 | 73.5 | +27.5 |
# | G (poids 6) | 77 | 77 | 0 |
# | **Total** | | | **+1.5** |
#
# La différence totale n'est que de **1.5 points**, ce qui est extrêmement faible.
#
# ### Pourquoi aucun trade-off n'est valide ?
#
# Pour qu'un trade-off soit valide, il faut que la somme des contributions soit **strictement positive**.
#
# - Le plus gros pro (Anatomie: +144) ne suffit pas à couvrir deux cons : 144 - 70 - 70 = +4, mais alors Diagnostic (-66) reste non couvert
# - Si Anatomie couvre B et C, il reste D (-66) à couvrir par E (+36) et F (+27.5) = 63.5, ce qui est insuffisant
#
# **Le certificat de non-existence prouve qu'il est impossible de construire une explication simple pour justifier a1 > a2.**
#
#
# On ne peut donc pas expliquer simplement à a2 pourquoi il est moins bien classé que a1. La préférence existe (score 3566 vs 3564.5), mais elle est trop marginale pour être justifiée par des trade-offs compensatoires.

# %% [markdown]
# # Dataset RATP

# %% [markdown]
# ### Importation du dataset et des poids associés à chaque variable.

# %%
ratp_data = pd.read_excel("RATP.xlsx", skiprows=1, skipfooter=2)
ratp_data.drop(columns=["Unnamed: 0"], inplace=True)
ratp_data.rename(columns={f"Unnamed: {i}": ratp_data.iloc[0, :].values[i-1] for i in range(1, ratp_data.shape[1]+1)}, inplace=True)
ratp_data.drop(index=0, inplace=True)
ratp_data.reset_index(drop=True, inplace=True)

weights = pd.read_excel("RATP.xlsx")
weights = weights.iloc[-1, 1:].values[1:]

# %%
ratp_data
# Out:
#                           Metro station peak-entering-passengers/h  \
# 0                       Odéon (Ligne 4)                      85000
# 1               Place d'Italie (Lign 6)                      81000
# 2                     Jussieu (Ligne 7)                      74000
# 3                      Nation (Ligne 9)                      74000
# 4  La Motte Picquet-Grenelle (Ligne 10)                      72000
# 5             Porte d'Orléans (Ligne 4)                      71000
# 6                    Daumenil (Ligne 6)                      79000
# 7                  Vaugirard (Ligne 12)                      57000
# 8                   Oberkampf (Ligne 9)                      84000
# 9             Reuilly-Diderot (Ligne 1)                      72000
#
#   peak-passing-passengers/h off-peak-entering-passengers/h  \
# 0                      8100                          35500
# 1                      8100                          37500
# 2                      8900                          37000
# 3                      7100                          42000
# 4                      7500                          33000
# 5                      7300                          31500
# 6                      6900                          39000
# 7                      7600                          40500
# 8                      7900                          34000
# 9                      8700                          36000
#
#   off-peak-passing-passengers/h strategic priority [0,10]  \
# 0                          3450                        75
# 1                          3150                        67
# 2                          4050                        68
# 3                          4550                        77
# 4                          4250                        88
# 5                          4600                        76
# 6                          3800                        67
# 7                          3800                        82
# 8                          3300                        74
# 9                          4000                        66
#
#   Station degradation level ([0,20]  scale) connectivity index [0,100]
# 0                                      16.2                         88
# 1                                      17.6                         95
# 2                                      16.8                         79
# 3                                      15.2                         73
# 4                                      13.2                         93
# 5                                      15.8                         93
# 6                                      16.8                         79
# 7                                      17.2                         77
# 8                                      15.8                         85
# 9                                      16.6                         78

# %% [markdown]
# ### Calcul des scores en fonction des poids

# %% [markdown]
# On ajoute 2 colonnes au dataset :
# - Le score de priorité obtenu par la somme pondéré des valeurs des différentes variables pour chaque station.
# - Le rang de priorité de chaque station; on trie dans l'ordre décroissant les stations par rapport à leur score.

# %%
ratp_data['Score'] = ratp_data.iloc[:, 1:].values @ weights
ratp_data.sort_values(by='Score', ascending=False, inplace=True)
ratp_data['Rank'] = np.arange(1, ratp_data.shape[0]+1)
ratp_data.reset_index(drop=True, inplace=True)
ratp_data
# Out:
#                           Metro station peak-entering-passengers/h  \
# 0                       Odéon (Ligne 4)                      85000
# 1               Place d'Italie (Lign 6)                      81000
# 2                     Jussieu (Ligne 7)                      74000
# 3                      Nation (Ligne 9)                      74000
# 4  La Motte Picquet-Grenelle (Ligne 10)                      72000
# 5             Porte d'Orléans (Ligne 4)                      71000
# 6             Reuilly-Diderot (Ligne 1)                      72000
# 7                   Oberkampf (Ligne 9)                      84000
# 8                    Daumenil (Ligne 6)                      79000
# 9                  Vaugirard (Ligne 12)                      57000
#
#   peak-passing-passengers/h off-peak-entering-passengers/h  \
# 0                      8100                          35500
# 1                      8100                          37500
# 2                      8900                          37000
# 3                      7100                          42000
# 4                      7500                          33000
# 5                      7300                          31500
# 6                      8700                          36000
# 7                      7900                          34000
# 8                      6900                          39000
# 9                      7600                          40500
#
#   off-peak-passing-passengers/h strategic priority [0,10]  \
# 0                          3450                        75
# 1                          3150                        67
# 2                          4050                        68
# 3                          4550                        77
# 4                          4250                        88
# 5                          4600                        76
# 6                          4000                        66
# 7                          3300                        74
# 8                          3800                        67
# 9                          3800                        82
#
#   Station degradation level ([0,20]  scale) connectivity index [0,100]  \
# 0                                      16.2                         88
# 1                                      17.6                         95
# 2                                      16.8                         79
# 3                                      15.2                         73
# 4                                      13.2                         93
# 5                                      15.8                         93
# 6                                      16.6                         78
# 7                                      15.8                         85
# 8                                      16.8                         79
# 9                                      17.2                         77
#
#          Score  Rank
# 0  9515.747608     1
# 1  9486.187251     2
# 2  9462.001505     3
# 3  9413.630012     4
# 4  9376.007739     5
# 5  9354.509298     6
# 6  9265.828227     7
# 7  9260.453617     8
# 8  9171.772546     9
# 9  9123.401053    10

# %% [markdown]
# ## Justification du top1
#
# On montre Odéon (Ligne 4) > Place d'Italie (Ligne 6)

# %%
odeon = ratp_data.iloc[0].values.flatten()[1:-2].astype(float) 
italie = ratp_data.iloc[1].values.flatten()[1:-2].astype(float)

pros = [i for i in range(len(odeon)) if odeon[i] > italie[i]]
cons = [i for i in range(len(odeon)) if odeon[i] < italie[i]]
neutral = [i for i in range(len(odeon)) if odeon[i] == italie[i]]

print(f"{len(pros)} pros:", [ratp_data.columns[i+1] for i in pros])
print(f"{len(cons)} cons:", [ratp_data.columns[i+1] for i in cons])
print(f"{len(neutral)} neutral:", [ratp_data.columns[i+1] for i in neutral])
# Out:
# 3 pros: ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# 3 cons: ['off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# 1 neutral: ['peak-passing-passengers/h']

# %% [markdown]
# On a 3 pros et 3 cons. L'explication 1-1 paraît être la plus adaptée dans un premier temps.

# %%
result_odeon_italie, expl_odeon_italie = find_explanation_1_1(odeon, italie, weights, ratp_data.columns[1:-2], 'Odeon', 'Place d\'Italie')
# Out:
# === Analyse Odeon > Place d'Italie ===
# pros(Odeon,Place d'Italie):   ['peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# cons(Odeon,Place d'Italie):   ['off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# Contributions: [85.99376545200472 0.0 -75.24454477050415 96.7429861335053
#  128.9906481780071 -94.0556809631303 -112.86681715575621]
# trade-offs valides(Odeon,Place d'Italie): [('peak-entering-passengers/h', 'off-peak-entering-passengers/h', 10.749220681500574), ('off-peak-passing-passengers/h', 'off-peak-entering-passengers/h', 21.49844136300115), ('off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 2.687305170374998), ('strategic priority [0,10]', 'off-peak-entering-passengers/h', 53.74610340750294), ('strategic priority [0,10]', 'Station degradation level ([0,20]  scale)', 34.93496721487679), ('strategic priority [0,10]', 'connectivity index [0,100]', 16.123831022250883)]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : peak-entering-passengers/h vs. off-peak-entering-passengers/h
#  Contributions : 85.99376545200472 + (-75.24454477050415) = 10.749220681500574
# Trade-off : off-peak-passing-passengers/h vs. Station degradation level ([0,20]  scale)
#  Contributions : 96.7429861335053 + (-94.0556809631303) = 2.687305170374998
# Trade-off : strategic priority [0,10] vs. connectivity index [0,100]
#  Contributions : 128.9906481780071 + (-112.86681715575621) = 16.123831022250883

# %% [markdown]
# ## Justification du top3

# %% [markdown]
# Jussieu est la station ayant le 3ème score de priorité le plus élevé. On va expliquer ce score par rapport à la station top2 (i.e Place d'Italie > Jussieu) et à la station top4 (i.e Jussieu > Nation).

# %% [markdown]
# ### Justification Place d'Italie > Jussieu

# %%
italie = ratp_data.iloc[1].values.flatten()[1:-2].astype(float)
jussieu = ratp_data.iloc[2].values.flatten()[1:-2].astype(float) 

pros = [i for i in range(len(italie)) if italie[i] > jussieu[i]]
cons = [i for i in range(len(italie)) if italie[i] < jussieu[i]]
neutral = [i for i in range(len(italie)) if italie[i] == jussieu[i]]

print(f"{len(pros)} pros:", [ratp_data.columns[i+1] for i in pros])
print(f"{len(cons)} cons:", [ratp_data.columns[i+1] for i in cons])
print(f"{len(neutral)} neutral:", [ratp_data.columns[i+1] for i in neutral])
# Out:
# 4 pros: ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# 3 cons: ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# 0 neutral: []

# %% [markdown]
# On a plus de pros que de cons. On peut essayer une explication (1-1) et si cela ne marche pas une explication (m-1) devrait marcher.

# %%
result_italie_jussieu, expl_italie_jussieu = find_explanation_1_1(italie, jussieu, weights, ratp_data.columns[1:-2], 'Place d\'Italie', 'Jussieu')
# Out:
# === Analyse Place d'Italie > Jussieu ===
# pros(Place d'Italie,Jussieu):   ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# cons(Place d'Italie,Jussieu):   ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Contributions: [150.48908954100827 -150.48908954100827 18.811136192626037
#  -290.2289584005159 -16.123831022250886 53.746103407503 257.9812963560142]
# trade-offs valides(Place d'Italie,Jussieu): [('peak-entering-passengers/h', 'strategic priority [0,10]', 134.36525851875737), ('off-peak-entering-passengers/h', 'strategic priority [0,10]', 2.6873051703751507), ('Station degradation level ([0,20]  scale)', 'strategic priority [0,10]', 37.62227238525212), ('connectivity index [0,100]', 'peak-passing-passengers/h', 107.49220681500591), ('connectivity index [0,100]', 'strategic priority [0,10]', 241.8574653337633)]
# Pas de solution (certificat de non-existence).

# %% [markdown]
# L'explication (1-1) ne marche pas, on essaie donc d'expliquer avec une méthode (m-1) pour compenser un con par plusieurs pros.

# %%
result_italie_jussieu, expl_italie_jussieu = find_explanation_m_1(italie, jussieu, weights, ratp_data.columns[1:-2], 'Place d\'Italie', 'Jussieu')
# Out:
# === Analyse Place d'Italie > Jussieu (type m-1) ===
# pros(Place d'Italie,Jussieu):   ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]'] contributions: [150.48908954100827, 18.811136192626037, 53.746103407503, 257.9812963560142]
# cons(Place d'Italie,Jussieu):   ['peak-passing-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]'] contributions: [-150.48908954100827, -290.2289584005159, -16.123831022250886]
#
#  Explication (m-1) trouvée, longueur = 3
#   Trade-off: ['peak-entering-passengers/h'] vs (peak-passing-passengers/h)
#     Contributions: [150.48908954100827] + -150.5 = 0.0
#   Trade-off: ['Station degradation level ([0,20]  scale)', 'connectivity index [0,100]'] vs (off-peak-passing-passengers/h)
#     Contributions: [53.746103407503, 257.9812963560142] + -290.2 = 21.5
#   Trade-off: ['off-peak-entering-passengers/h'] vs (strategic priority [0,10])
#     Contributions: [18.811136192626037] + -16.1 = 2.7

# %% [markdown]
# ### Justification Jussieu > Nation

# %%
jussieu = ratp_data.iloc[2].values.flatten()[1:-2].astype(float)
nation = ratp_data.iloc[3].values.flatten()[1:-2].astype(float)

pros = [i for i in range(len(jussieu)) if jussieu[i] > nation[i]]
cons = [i for i in range(len(jussieu)) if jussieu[i] < nation[i]]
neutral = [i for i in range(len(jussieu)) if jussieu[i] == nation[i]]

print(f"{len(pros)} pros:", [ratp_data.columns[i+1] for i in pros])
print(f"{len(cons)} cons:", [ratp_data.columns[i+1] for i in cons])
print(f"{len(neutral)} neutral:", [ratp_data.columns[i+1] for i in neutral])
# Out:
# 3 pros: ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# 3 cons: ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# 1 neutral: ['peak-entering-passengers/h']

# %% [markdown]
# On a 3 pros et 3 cons, une explication (1-1) semble logique.

# %%
result_jussieu_nation, expl_jussieu_nation = find_explanation_1_1(jussieu, nation, weights, ratp_data.columns[1:-2], 'Jussieu', 'Nation')
# Out:
# === Analyse Jussieu > Nation ===
# pros(Jussieu,Nation):   ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]']
# cons(Jussieu,Nation):   ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]']
# Contributions: [0.0 338.6004514672686 -188.11136192626037 -161.23831022250883
#  -145.114479200258 107.49220681500587 96.74298613350533]
# trade-offs valides(Jussieu,Nation): [('peak-passing-passengers/h', 'off-peak-entering-passengers/h', 150.48908954100824), ('peak-passing-passengers/h', 'off-peak-passing-passengers/h', 177.36214124475978), ('peak-passing-passengers/h', 'strategic priority [0,10]', 193.48597226701062)]
# Pas de solution (certificat de non-existence).

# %% [markdown]
# L'explication (1-1) ne marche pas. On voit une contribution assez grande par rapport aux autres cons mais que les autres pros sont tous plus petits que les cons. On tente donc une explication mixte.

# %%
result_jussieu_nation, expl_jussieu_nation = find_explanation_mixed(jussieu, nation, weights, ratp_data.columns[1:-2], 'Jussieu', 'Nation')
# Out:
# === Analyse Jussieu > Nation (type mixte) ===
# pros(Jussieu,Nation):   ['peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)', 'connectivity index [0,100]'] contributions: [np.float64(338.6004514672686), np.float64(107.49220681500587), np.float64(96.74298613350533)]
# cons(Jussieu,Nation):   ['off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'strategic priority [0,10]'] contributions: [np.float64(-188.11136192626037), np.float64(-161.23831022250883), np.float64(-145.114479200258)]
#
#  Explication mixte trouvée, longueur = 2
#   Trade-off (m-1): ['Station degradation level ([0,20]  scale)', 'connectivity index [0,100]'] vs (off-peak-entering-passengers/h)
#     Contributions: [np.float64(107.49220681500587), np.float64(96.74298613350533)] + -188.1 = 16.1
#   Trade-off (1-m): (peak-passing-passengers/h) vs ['off-peak-passing-passengers/h', 'strategic priority [0,10]']
#     Contributions: 338.6 + [np.float64(-161.23831022250883), np.float64(-145.114479200258)] = 32.2

# %% [markdown]
# On voit que ``peak-passing-passengers/h`` réussi à absorber les 2 cons ``off-peak-passing-passengers/h`` et ``strategic priority [0,10]`` et que les 2 pros ``Station degradation level ([0,20]  scale)`` et  ``connectivity index [0,100]`` compensent ``off-peak-entering-passengers/h``

# %% [markdown]
# ## Justification top5
#
# La Motte Picquet-Grenelle est la station ayant le 5ème score de priorité le plus élevé. On va expliquer ce score par rapport à la station top4 (i.e Nation > La Motte Picquet-Grenelle) et à la station top6 (i.e La Motte Picquet-Grenelle > Porte d'Orléans).

# %% [markdown]
# ### On montre Nation > La Motte Picquet-Grenelle

# %%
nation = ratp_data.iloc[3].values.flatten()[1:-2].astype(float)
lamotte = ratp_data.iloc[4].values.flatten()[1:-2].astype(float)

pros = [i for i in range(len(nation)) if nation[i] > lamotte[i]]
cons = [i for i in range(len(nation)) if nation[i] < lamotte[i]]
neutral = [i for i in range(len(nation)) if nation[i] == lamotte[i]]

print(f"{len(pros)} pros:", [ratp_data.columns[i+1] for i in pros])
print(f"{len(cons)} cons:", [ratp_data.columns[i+1] for i in cons])
print(f"{len(neutral)} neutral:", [ratp_data.columns[i+1] for i in neutral])
# Out:
# 4 pros: ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# 3 cons: ['peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# 0 neutral: []

# %% [markdown]
# On a plus de pros que de cons, on peut commencer par essayer une explication 1-1 et si celle-ci ne marche pas on pourra utiliser une explication m-1 pour que 2pros puissent s'additionner pour compenser un con.

# %%
result_nation_lamotte, expl_nation_lamotte = find_explanation_1_1(nation, lamotte, weights, ratp_data.columns[1:-2], 'Nation', 'La Motte-Picquet')
# Out:
# === Analyse Nation > La Motte-Picquet ===
# pros(Nation,La Motte-Picquet):   ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# cons(Nation,La Motte-Picquet):   ['peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]']
# Contributions: [42.99688272600236 -75.24454477050413 338.60045146726867 96.7429861335053
#  -177.36214124475975 134.36525851875737 -322.4766204450177]
# trade-offs valides(Nation,La Motte-Picquet): [('off-peak-entering-passengers/h', 'peak-passing-passengers/h', 263.3559066967645), ('off-peak-entering-passengers/h', 'strategic priority [0,10]', 161.23831022250891), ('off-peak-entering-passengers/h', 'connectivity index [0,100]', 16.123831022250954), ('off-peak-passing-passengers/h', 'peak-passing-passengers/h', 21.498441363001163), ('Station degradation level ([0,20]  scale)', 'peak-passing-passengers/h', 59.12071374825324)]
# Pas de solution (certificat de non-existence).

# %%
result_nation_lamotte, expl_nation_lamotte = find_explanation_m_1(nation, lamotte, weights, ratp_data.columns[1:-2], 'Nation', 'La Motte-Picquet')
# Out:
# === Analyse Nation > La Motte-Picquet (type m-1) ===
# pros(Nation,La Motte-Picquet):   ['peak-entering-passengers/h', 'off-peak-entering-passengers/h', 'off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)'] contributions: [42.99688272600236, 338.60045146726867, 96.7429861335053, 134.36525851875737]
# cons(Nation,La Motte-Picquet):   ['peak-passing-passengers/h', 'strategic priority [0,10]', 'connectivity index [0,100]'] contributions: [-75.24454477050413, -177.36214124475975, -322.4766204450177]
#
#  Explication (m-1) trouvée, longueur = 3
#   Trade-off: ['off-peak-passing-passengers/h'] vs (peak-passing-passengers/h)
#     Contributions: [96.7429861335053] + -75.2 = 21.5
#   Trade-off: ['peak-entering-passengers/h', 'Station degradation level ([0,20]  scale)'] vs (strategic priority [0,10])
#     Contributions: [42.99688272600236, 134.36525851875737] + -177.4 = -0.0
#   Trade-off: ['off-peak-entering-passengers/h'] vs (connectivity index [0,100])
#     Contributions: [338.60045146726867] + -322.5 = 16.1

# %% [markdown]
# En effet, on a ``peak-entering-passengers/h``, ``Station degradation level ([0,20]  scale)`` qui compensent ``strategic priority [0,10]``

# %% [markdown]
# ### On montre La Motte Picquet-Grenelle > Porte d'Orléns

# %%
lamotte = ratp_data.iloc[4].values.flatten()[1:-2].astype(float)
orleans = ratp_data.iloc[5].values.flatten()[1:-2].astype(float)

pros = [i for i in range(len(lamotte)) if lamotte[i] > orleans[i]]
cons = [i for i in range(len(lamotte)) if lamotte[i] < orleans[i]]
neutral = [i for i in range(len(lamotte)) if lamotte[i] == orleans[i]]

print(f"{len(pros)} pros:", [ratp_data.columns[i+1] for i in pros])
print(f"{len(cons)} cons:", [ratp_data.columns[i+1] for i in cons])
print(f"{len(neutral)} neutral:", [ratp_data.columns[i+1] for i in neutral])
# Out:
# 4 pros: ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]']
# 2 cons: ['off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)']
# 1 neutral: ['connectivity index [0,100]']

# %% [markdown]
# Pour que leurs scores soient aussi proches mais avec 4 pros contre 2 cons, les cons doivent être très grand. On va donc directement utiliser l'explication (m-1).

# %%
result_lamotte_orleans, expl_lamotte_orleans = find_explanation_m_1(lamotte, orleans, weights, ratp_data.columns[1:-2], 'La Motte-Picquet', 'Orléans')
# Out:
# === Analyse La Motte-Picquet > Orléans (type m-1) ===
# pros(La Motte-Picquet,Orléans):   ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h', 'strategic priority [0,10]'] contributions: [21.49844136300118, 37.62227238525207, 56.433408577878104, 193.48597226701065]
# cons(La Motte-Picquet,Orléans):   ['off-peak-passing-passengers/h', 'Station degradation level ([0,20]  scale)'] contributions: [-112.8668171557562, -174.67483607438456]
#
#  Explication (m-1) trouvée, longueur = 2
#   Trade-off: ['peak-entering-passengers/h', 'peak-passing-passengers/h', 'off-peak-entering-passengers/h'] vs (off-peak-passing-passengers/h)
#     Contributions: [21.49844136300118, 37.62227238525207, 56.433408577878104] + -112.9 = 2.7
#   Trade-off: ['strategic priority [0,10]'] vs (Station degradation level ([0,20]  scale))
#     Contributions: [193.48597226701065] + -174.7 = 18.8

# %% [markdown]
# Notre intuition était la bonne, il a fallu 3 pros pour compenser ``off-peak-passing-passengers/h``.

# %% [markdown]
# # Dataset Breast Cancer

# %%
# Imports for breast cancer analysis
import random
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, roc_auc_score

# %%
# Load breast cancer dataset
df = pd.read_csv("breastcancer_processed.csv")
print(f"Dataset: {df.shape[0]} patients, {df.shape[1]} features")

# Rename target column
df = df.rename(columns={"Benign": "Malign"})
target_col = "Malign"
print(f"Target distribution:")
print(df[target_col].value_counts())

# Prepare data and normalize
X = df.drop(columns=[target_col])
y = df[target_col].copy()
feature_names_bc = X.columns.tolist()

X_train_bc, X_test_bc, y_train_bc, y_test_bc = train_test_split(
    X, y, test_size=0.25, random_state=0, stratify=y
)

scaler_bc = StandardScaler()
X_train_s_bc = scaler_bc.fit_transform(X_train_bc)
X_test_s_bc = scaler_bc.transform(X_test_bc)

# Train model
clf_bc = LogisticRegression()
clf_bc.fit(X_train_s_bc, y_train_bc)

proba_test_bc = clf_bc.predict_proba(X_test_s_bc)[:, 1]
pred_test_bc = clf_bc.predict(X_test_s_bc)

print(f"\nModel Performance:")
print(f"  Accuracy: {accuracy_score(y_test_bc, pred_test_bc):.4f}")
print(f"  AUC: {roc_auc_score(y_test_bc, proba_test_bc):.4f}")

w_bc = clf_bc.coef_.ravel()
b_bc = clf_bc.intercept_[0]

print(f"\nBias: {b_bc:.3f}")
print("Weights by feature:")
for i, (feature_name, weight) in enumerate(zip(feature_names_bc, w_bc)):
    print(f"  {i}. {feature_name}: {weight:.3f}")
# Out:
# Dataset: 683 patients, 10 features
# Target distribution:
# Malign
# 0    444
# 1    239
# Name: count, dtype: int64
#
# Model Performance:
#   Accuracy: 0.9532
#   AUC: 0.9938
#
# Bias: -1.186
# Weights by feature:
#   0. ClumpThickness: 1.042
#   1. UniformityOfCellSize: 0.695
#   2. UniformityOfCellShape: 0.774
#   3. MarginalAdhesion: 0.803
#   4. SingleEpithelialCellSize: 0.446
#   5. BareNuclei: 1.044
#   6. BlandChromatin: 1.243
#   7. NormalNucleoli: 0.473
#   8. Mitoses: 0.562

# %% [markdown]
# ## Trade-off analysis

# %% [markdown]
# Dans l’analyse inter-classes, nous imposons toujours l’ordre de comparaison selon la préférence du modèle
# Comparer bénin > malin conduirait mécaniquement à des cas non-explicables sans intérêt explicatif.
# DE même en intra-classe on préfère mettre celui qui a un plus haut score en prmeier

# %%
# Configuration
np.random.seed(42)
random.seed(42)

n_samples_bc = len(X_test_s_bc)
n_trade_offs = 1000

w_prof = [0.416, 0.134, 0.247, 0.235, 0.11, 0.352, 0.304, 0.193, 0.226]

# Select weights to use prof or calculated
weights_used = w_prof  # or w_bc
print("Generating 1000 random pairs and analyzing trade-offs...\n")

# Generate unique random pairs with ordered comparison
all_pairs_bc = []
while len(all_pairs_bc) < n_trade_offs:
    idx1 = random.randint(0, n_samples_bc - 1)
    idx2 = random.randint(0, n_samples_bc - 1)
    if idx1 != idx2 and (idx1, idx2) not in all_pairs_bc and (idx2, idx1) not in all_pairs_bc:
        # For inter-class pairs, enforce order: malignant (1) > benign (0)
        if pred_test_bc[idx1] != pred_test_bc[idx2]:
            # Different classes: ensure malignant is first
            if pred_test_bc[idx1] == 0:  # idx1 is benign, idx2 is malignant
                idx1, idx2 = idx2, idx1
        else:
            # Same class: ensure higher score is first
            if proba_test_bc[idx1] < proba_test_bc[idx2]:
                idx1, idx2 = idx2, idx1
        all_pairs_bc.append((idx1, idx2))

# Analyze all pairs (silent mode)
results_bc = []
all_cons_values_bc = []
all_pros_values_bc = []
cons_by_feature_bc = {i: {'count': 0, 'values': []} for i in range(len(feature_names_bc))}
pros_by_feature_bc = {i: {'count': 0, 'values': []} for i in range(len(feature_names_bc))}

print(f"Analysis in progress: ", end="")
for idx, (idx1, idx2) in enumerate(all_pairs_bc, 1):
    if idx % 20 == 0:
        print(f"{idx}...", end=" ", flush=True)
    
    x_pat = X_test_s_bc[idx1]
    y_pat = X_test_s_bc[idx2]
    
    # Calculate contributions
    contributions = np.array(weights_used) * (x_pat - y_pat)
    pros_idx = np.where(contributions > 1e-12)[0]
    cons_idx = np.where(contributions < -1e-12)[0]
    n_pros = len(pros_idx)
    n_cons = len(cons_idx)
    
    # Track cons and pros by feature
    if n_cons > 0:
        all_cons_values_bc.extend(contributions[contributions < -1e-12].tolist())
        for feat_idx in cons_idx:
            cons_by_feature_bc[feat_idx]['count'] += 1
            cons_by_feature_bc[feat_idx]['values'].append(contributions[feat_idx])
    
    if n_pros > 0:
        all_pros_values_bc.extend(contributions[contributions > 1e-12].tolist())
        for feat_idx in pros_idx:
            pros_by_feature_bc[feat_idx]['count'] += 1
            pros_by_feature_bc[feat_idx]['values'].append(contributions[feat_idx])
    
    # Determine explicability type (selective testing)
    if n_pros == 0 or n_cons == 0:
        explainability_type = "TRIVIAL"
        explanation_method = "None"
    else:
        status_1_1, _ = find_explanation_1_1(x_pat, y_pat, w_bc, feature_names_bc)
        if status_1_1 == 'OPTIMAL':
            explainability_type = "EXPLICABLE"
            explanation_method = "1-1"
        else:
            status_1_m, _ = find_explanation_1_m(x_pat, y_pat, w_bc, feature_names_bc)
            if status_1_m == 'OPTIMAL':
                explainability_type = "EXPLICABLE"
                explanation_method = "1-m"
            else:
                status_m_1, _ = find_explanation_m_1(x_pat, y_pat, w_bc, feature_names_bc)
                if status_m_1 == 'OPTIMAL':
                    explainability_type = "EXPLICABLE"
                    explanation_method = "m-1"
                else:
                    status_mixed, _ = find_explanation_mixed(x_pat, y_pat, w_bc, feature_names_bc, 'X', 'Y')
                    if status_mixed == 'OPTIMAL':
                        explainability_type = "EXPLICABLE"
                        explanation_method = "Mixed"
                    else:
                        explainability_type = "NON-EXPLICABLE"
                        explanation_method = "None"
    
    results_bc.append({
        'Idx1': idx1,
        'Idx2': idx2,
        'Pros': n_pros,
        'Cons': n_cons,
        'Type': explainability_type,
        'Method': explanation_method,
    })

print(f"{n_trade_offs}. Done!\n")

df_results_bc = pd.DataFrame(results_bc)
print("Analysis complete: 1000 pairs analyzed and data prepared")
# Out:
# Generating 1000 random pairs and analyzing trade-offs...
#
# Analysis in progress:
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'SingleEpithelialCellSize', 'BareNuclei', 'NormalNucleoli']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 1.09585966  0.          0.          0.          0.20156254  0.28673009
#  -0.50539378  0.15881513  0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'BlandChromatin', np.float64(0.590465879811786))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : ClumpThickness vs. BlandChromatin
#  Contributions : 1.0958596619454155 + (-0.5053937821336295) = 0.590465879811786
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['MarginalAdhesion']
# Contributions: [ 1.46114622  0.22770842  0.78694675 -0.55981059  0.20156254  0.86019026
#   1.01078756  0.31763026  0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(0.9013356223574901)), ('UniformityOfCellShape', 'MarginalAdhesion', np.float64(0.22713616006993154)), ('BareNuclei', 'MarginalAdhesion', np.float64(0.30037966764886637)), ('BlandChromatin', 'MarginalAdhesion', np.float64(0.4509769706975283))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BlandChromatin vs. MarginalAdhesion
#  Contributions : 1.010787564267259 + (-0.5598105935697307) = 0.4509769706975283
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BareNuclei', 'Mitoses']
# cons(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'BlandChromatin']
# Contributions: [-1.09585966  0.45541684 -1.04926234  0.83971589  0.40312509  1.72038052
#  -1.51618135  0.          0.99915221]
# trade-offs valides(X,Y): [('BareNuclei', 'ClumpThickness', np.float64(0.6245208604917787)), ('BareNuclei', 'UniformityOfCellShape', np.float64(0.6711181842509777)), ('BareNuclei', 'BlandChromatin', np.float64(0.20419917603630555))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BareNuclei', 'Mitoses']
# cons(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'BlandChromatin']
# Contributions: [-1.09585966  0.45541684 -1.04926234  0.83971589  0.40312509  1.72038052
#  -1.51618135  0.          0.99915221]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['UniformityOfCellSize', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BareNuclei', 'Mitoses'] contributions: [np.float64(0.4554168434908752), np.float64(0.8397158903545962), np.float64(0.40312508840317773), np.float64(1.7203805224371942), np.float64(0.9991522144597266)]
# cons(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'BlandChromatin'] contributions: [np.float64(-1.0958596619454155), np.float64(-1.0492623381862165), np.float64(-1.5161813464008886)]
#
#  Explication (m-1) trouvée, longueur = 3
#   Trade-off: ['SingleEpithelialCellSize', 'Mitoses'] vs (ClumpThickness)
#     Contributions: [np.float64(0.40312508840317773), np.float64(0.9991522144597266)] + -1.1 = 0.3
#   Trade-off: ['UniformityOfCellSize', 'MarginalAdhesion'] vs (UniformityOfCellShape)
#     Contributions: [np.float64(0.4554168434908752), np.float64(0.8397158903545962)] + -1.0 = 0.2
#   Trade-off: ['BareNuclei'] vs (BlandChromatin)
#     Contributions: [np.float64(1.7203805224371942)] + -1.5 = 0.2
#
# === Analyse X > Y ===
# pros(X,Y):   ['BlandChromatin']
# cons(X,Y):   ['ClumpThickness', 'SingleEpithelialCellSize']
# Contributions: [-0.36528655  0.          0.          0.         -0.20156254  0.
#   1.01078756  0.          0.        ]
# trade-offs valides(X,Y): [('BlandChromatin', 'ClumpThickness', np.float64(0.6455010102854539)), ('BlandChromatin', 'SingleEpithelialCellSize', np.float64(0.8092250200656701))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['BlandChromatin']
# cons(X,Y):   ['ClumpThickness', 'SingleEpithelialCellSize']
# Contributions: [-0.36528655  0.          0.          0.         -0.20156254  0.
#   1.01078756  0.          0.        ]
#
#  Explication (1-m) trouvée, longueur = 1
#   Trade-off: (BlandChromatin) vs ['ClumpThickness', 'SingleEpithelialCellSize']
#     Contributions: 1.0 + [np.float64(-0.36528655398180515), np.float64(-0.20156254420158895)] = 0.4
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion']
# cons(X,Y):   ['SingleEpithelialCellSize', 'BlandChromatin']
# Contributions: [ 1.46114622  0.22770842  0.26231558  0.2799053  -0.20156254  0.
#  -0.50539378  0.          0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'SingleEpithelialCellSize', np.float64(1.259583671725632)), ('ClumpThickness', 'BlandChromatin', np.float64(0.9557524337935913)), ('UniformityOfCellSize', 'SingleEpithelialCellSize', np.float64(0.026145877543848645)), ('UniformityOfCellShape', 'SingleEpithelialCellSize', np.float64(0.060753040344965176)), ('MarginalAdhesion', 'SingleEpithelialCellSize', np.float64(0.07834275258327641))]
#
# Explication (1-1) trouvée de longueur 2
# Trade-off : ClumpThickness vs. BlandChromatin
#  Contributions : 1.4611462159272208 + (-0.5053937821336295) = 0.9557524337935913
# Trade-off : MarginalAdhesion vs. SingleEpithelialCellSize
#  Contributions : 0.27990529678486537 + (-0.20156254420158895) = 0.07834275258327641
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness']
# cons(X,Y):   ['SingleEpithelialCellSize']
# Contributions: [ 0.36528655  0.          0.          0.         -0.20156254  0.
#   0.          0.          0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'SingleEpithelialCellSize', np.float64(0.16372400978021626))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : ClumpThickness vs. SingleEpithelialCellSize
#  Contributions : 0.3652865539818052 + (-0.20156254420158895) = 0.16372400978021626
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'BareNuclei', 'BlandChromatin']
# cons(X,Y):   ['ClumpThickness', 'NormalNucleoli', 'Mitoses']
# Contributions: [-0.73057311  0.68312527  0.          0.          0.          0.86019026
#   1.51618135 -0.63526051 -0.66610148]
# trade-offs valides(X,Y): [('UniformityOfCellSize', 'NormalNucleoli', np.float64(0.04786475448976357)), ('UniformityOfCellSize', 'Mitoses', np.float64(0.017023788929828254)), ('BareNuclei', 'ClumpThickness', np.float64(0.1296171532549868)), ('BareNuclei', 'NormalNucleoli', np.float64(0.224929750472048)), ('BareNuclei', 'Mitoses', np.float64(0.19408878491211268)), ('BlandChromatin', 'ClumpThickness', np.float64(0.7856082384372783)), ('BlandChromatin', 'NormalNucleoli', np.float64(0.8809208356543395)), ('BlandChromatin', 'Mitoses', np.float64(0.8500798700944042))]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : UniformityOfCellSize vs. NormalNucleoli
#  Contributions : 0.6831252652363127 + (-0.6352605107465491) = 0.04786475448976357
# Trade-off : BareNuclei vs. Mitoses
#  Contributions : 0.8601902612185971 + (-0.6661014763064844) = 0.19408878491211268
# Trade-off : BlandChromatin vs. ClumpThickness
#  Contributions : 1.5161813464008886 + (-0.7305731079636103) = 0.7856082384372783
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['MarginalAdhesion', 'BareNuclei']
# Contributions: [ 0.73057311  0.68312527  0.52463117 -0.2799053   0.20156254 -2.2938407
#   0.50539378  0.95289077  0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(0.4506678111787449)), ('UniformityOfCellSize', 'MarginalAdhesion', np.float64(0.40321996845144725)), ('UniformityOfCellShape', 'MarginalAdhesion', np.float64(0.24472587230824272)), ('BlandChromatin', 'MarginalAdhesion', np.float64(0.2254884853487641)), ('NormalNucleoli', 'MarginalAdhesion', np.float64(0.6729854693349583))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['MarginalAdhesion', 'BareNuclei']
# Contributions: [ 0.73057311  0.68312527  0.52463117 -0.2799053   0.20156254 -2.2938407
#   0.50539378  0.95289077  0.        ]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BlandChromatin', 'NormalNucleoli'] contributions: [np.float64(0.7305731079636103), np.float64(0.6831252652363127), np.float64(0.5246311690931081), np.float64(0.20156254420158887), np.float64(0.5053937821336295), np.float64(0.9528907661198237)]
# cons(X,Y):   ['MarginalAdhesion', 'BareNuclei'] contributions: [np.float64(-0.2799052967848654), np.float64(-2.2938406965829254)]
#
#  Explication (m-1) trouvée, longueur = 2
#   Trade-off: ['BlandChromatin'] vs (MarginalAdhesion)
#     Contributions: [np.float64(0.5053937821336295)] + -0.3 = 0.2
#   Trade-off: ['ClumpThickness', 'UniformityOfCellSize', 'NormalNucleoli'] vs (BareNuclei)
#     Contributions: [np.float64(0.7305731079636103), np.float64(0.6831252652363127), np.float64(0.9528907661198237)] + -2.3 = 0.1
# 20...
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 1.09585966  0.          0.          0.          0.          0.
#  -0.50539378  0.          0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'BlandChromatin', np.float64(0.5904658798117858))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : ClumpThickness vs. BlandChromatin
#  Contributions : 1.0958596619454155 + (-0.5053937821336297) = 0.5904658798117858
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'BlandChromatin']
# cons(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape']
# Contributions: [ 1.09585966 -0.22770842 -0.26231558  0.          0.          0.
#   0.50539378  0.          0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'UniformityOfCellSize', np.float64(0.8681512401999779)), ('ClumpThickness', 'UniformityOfCellShape', np.float64(0.8335440773988614)), ('BlandChromatin', 'UniformityOfCellSize', np.float64(0.27768536038819214)), ('BlandChromatin', 'UniformityOfCellShape', np.float64(0.2430781975870756))]
#
# Explication (1-1) trouvée de longueur 2
# Trade-off : ClumpThickness vs. UniformityOfCellShape
#  Contributions : 1.0958596619454155 + (-0.2623155845465541) = 0.8335440773988614
# Trade-off : BlandChromatin vs. UniformityOfCellSize
#  Contributions : 0.5053937821336297 + (-0.2277084217454376) = 0.27768536038819214
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli']
# cons(X,Y):   ['MarginalAdhesion', 'BareNuclei']
# Contributions: [ 0.          0.68312527  1.04926234 -0.2799053   1.20937527 -0.28673009
#   0.          0.79407564  0.        ]
# trade-offs valides(X,Y): [('UniformityOfCellSize', 'MarginalAdhesion', np.float64(0.4032199684514473)), ('UniformityOfCellSize', 'BareNuclei', np.float64(0.396395178163447)), ('UniformityOfCellShape', 'MarginalAdhesion', np.float64(0.7693570414013511)), ('UniformityOfCellShape', 'BareNuclei', np.float64(0.7625322511133508)), ('SingleEpithelialCellSize', 'MarginalAdhesion', np.float64(0.9294699684246679)), ('SingleEpithelialCellSize', 'BareNuclei', np.float64(0.9226451781366676)), ('NormalNucleoli', 'MarginalAdhesion', np.float64(0.514170341648321)), ('NormalNucleoli', 'BareNuclei', np.float64(0.5073455513603207))]
#
# Explication (1-1) trouvée de longueur 2
# Trade-off : SingleEpithelialCellSize vs. BareNuclei
#  Contributions : 1.2093752652095333 + (-0.2867300870728657) = 0.9226451781366676
# Trade-off : NormalNucleoli vs. MarginalAdhesion
#  Contributions : 0.7940756384331864 + (-0.27990529678486537) = 0.514170341648321
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['MarginalAdhesion']
# Contributions: [ 2.19171932  0.45541684  0.         -0.2799053   0.20156254  0.28673009
#   0.50539378  0.15881513  0.66610148]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(1.9118140271059656)), ('UniformityOfCellSize', 'MarginalAdhesion', np.float64(0.17551154670600982)), ('BareNuclei', 'MarginalAdhesion', np.float64(0.006824790288000371)), ('BlandChromatin', 'MarginalAdhesion', np.float64(0.22548848534876414)), ('Mitoses', 'MarginalAdhesion', np.float64(0.38619617952161905))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : Mitoses vs. MarginalAdhesion
#  Contributions : 0.6661014763064844 + (-0.27990529678486537) = 0.38619617952161905
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'BlandChromatin']
# cons(X,Y):   ['MarginalAdhesion']
# Contributions: [ 0.36528655  0.          0.         -0.2799053   0.          0.
#   1.01078756  0.          0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(0.08538125719693984)), ('BlandChromatin', 'MarginalAdhesion', np.float64(0.7308822674823936))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BlandChromatin vs. MarginalAdhesion
#  Contributions : 1.010787564267259 + (-0.27990529678486537) = 0.7308822674823936
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'BareNuclei', 'Mitoses']
# cons(X,Y):   ['MarginalAdhesion', 'BlandChromatin', 'NormalNucleoli']
# Contributions: [ 2.55700588  0.          0.         -0.2799053   0.          1.43365044
#  -1.51618135 -0.15881513  0.33305074]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(2.2771005810877707)), ('ClumpThickness', 'BlandChromatin', np.float64(1.0408245314717475)), ('ClumpThickness', 'NormalNucleoli', np.float64(2.3981907501859987)), ('BareNuclei', 'MarginalAdhesion', np.float64(1.153745138579463)), ('BareNuclei', 'NormalNucleoli', np.float64(1.2748353076776913)), ('Mitoses', 'MarginalAdhesion', np.float64(0.053145441368376845)), ('Mitoses', 'NormalNucleoli', np.float64(0.17423561046660493))]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : ClumpThickness vs. BlandChromatin
#  Contributions : 2.557005877872636 + (-1.5161813464008886) = 1.0408245314717475
# Trade-off : BareNuclei vs. MarginalAdhesion
#  Contributions : 1.4336504353643285 + (-0.27990529678486537) = 1.153745138579463
# Trade-off : Mitoses vs. NormalNucleoli
#  Contributions : 0.3330507381532422 + (-0.15881512768663728) = 0.17423561046660493
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-1.46114622  0.45541684  0.          0.          0.          0.
#   1.01078756  0.31763026  0.33305074]
# trade-offs valides(X,Y): []
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-1.46114622  0.45541684  0.          0.          0.          0.
#   1.01078756  0.31763026  0.33305074]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['UniformityOfCellSize', 'BlandChromatin', 'NormalNucleoli', 'Mitoses'] contributions: [np.float64(0.4554168434908752), np.float64(1.010787564267259), np.float64(0.31763025537327455), np.float64(0.3330507381532422)]
# cons(X,Y):   ['ClumpThickness'] contributions: [np.float64(-1.4611462159272208)]
#
#  Explication (m-1) trouvée, longueur = 1
#   Trade-off: ['UniformityOfCellSize', 'BlandChromatin'] vs (ClumpThickness)
#     Contributions: [np.float64(0.4554168434908752), np.float64(1.010787564267259)] + -1.5 = 0.0
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'MarginalAdhesion', 'BareNuclei', 'Mitoses']
# cons(X,Y):   ['UniformityOfCellSize', 'SingleEpithelialCellSize', 'NormalNucleoli']
# Contributions: [ 0.73057311 -0.45541684  0.          0.83971589 -0.40312509  1.43365044
#   0.         -1.42933615  0.33305074]
# trade-offs valides(X,Y): [('ClumpThickness', 'UniformityOfCellSize', np.float64(0.2751562644727351)), ('ClumpThickness', 'SingleEpithelialCellSize', np.float64(0.3274480195604325)), ('MarginalAdhesion', 'UniformityOfCellSize', np.float64(0.38429904686372107)), ('MarginalAdhesion', 'SingleEpithelialCellSize', np.float64(0.4365908019514185)), ('BareNuclei', 'UniformityOfCellSize', np.float64(0.9782335918734533)), ('BareNuclei', 'SingleEpithelialCellSize', np.float64(1.0305253469611506)), ('BareNuclei', 'NormalNucleoli', np.float64(0.0043142861845928415))]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : ClumpThickness vs. UniformityOfCellSize
#  Contributions : 0.7305731079636103 + (-0.4554168434908752) = 0.2751562644727351
# Trade-off : MarginalAdhesion vs. SingleEpithelialCellSize
#  Contributions : 0.8397158903545963 + (-0.4031250884031778) = 0.4365908019514185
# Trade-off : BareNuclei vs. NormalNucleoli
#  Contributions : 1.4336504353643285 + (-1.4293361491797356) = 0.0043142861845928415
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['ClumpThickness', 'SingleEpithelialCellSize']
# Contributions: [-1.09585966  1.13854211  1.31157792  1.11962119 -0.20156254  0.
#   0.50539378  0.47644538  0.        ]
# trade-offs valides(X,Y): [('UniformityOfCellSize', 'ClumpThickness', np.float64(0.042682446781772354)), ('UniformityOfCellSize', 'SingleEpithelialCellSize', np.float64(0.9369795645255989)), ('UniformityOfCellShape', 'ClumpThickness', np.float64(0.2157182607873549)), ('UniformityOfCellShape', 'SingleEpithelialCellSize', np.float64(1.1100153785311815)), ('MarginalAdhesion', 'ClumpThickness', np.float64(0.023761525194046174)), ('MarginalAdhesion', 'SingleEpithelialCellSize', np.float64(0.9180586429378728)), ('BlandChromatin', 'SingleEpithelialCellSize', np.float64(0.30383123793204064)), ('NormalNucleoli', 'SingleEpithelialCellSize', np.float64(0.2748828388583231))]
#
# Explication (1-1) trouvée de longueur 2
# Trade-off : UniformityOfCellSize vs. ClumpThickness
#  Contributions : 1.1385421087271879 + (-1.0958596619454155) = 0.042682446781772354
# Trade-off : BlandChromatin vs. SingleEpithelialCellSize
#  Contributions : 0.5053937821336295 + (-0.20156254420158887) = 0.30383123793204064
# 40...
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['MarginalAdhesion']
# Contributions: [ 1.09585966  0.45541684  1.31157792 -0.2799053   0.20156254  2.58057078
#   0.50539378  1.11170589  0.33305074]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(0.8159543651605501)), ('UniformityOfCellSize', 'MarginalAdhesion', np.float64(0.17551154670600982)), ('UniformityOfCellShape', 'MarginalAdhesion', np.float64(1.031672625947905)), ('BareNuclei', 'MarginalAdhesion', np.float64(2.3006654868709258)), ('BlandChromatin', 'MarginalAdhesion', np.float64(0.22548848534876414)), ('NormalNucleoli', 'MarginalAdhesion', np.float64(0.8318005970215956)), ('Mitoses', 'MarginalAdhesion', np.float64(0.053145441368376845))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : Mitoses vs. MarginalAdhesion
#  Contributions : 0.3330507381532422 + (-0.27990529678486537) = 0.053145441368376845
#
# === Analyse X > Y ===
# pros(X,Y):   ['BareNuclei']
# cons(X,Y):   ['ClumpThickness', 'BlandChromatin']
# Contributions: [-0.36528655  0.          0.          0.          0.          1.14692035
#  -0.50539378  0.          0.        ]
# trade-offs valides(X,Y): [('BareNuclei', 'ClumpThickness', np.float64(0.7816337943096575)), ('BareNuclei', 'BlandChromatin', np.float64(0.641526566157833))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['BareNuclei']
# cons(X,Y):   ['ClumpThickness', 'BlandChromatin']
# Contributions: [-0.36528655  0.          0.          0.          0.          1.14692035
#  -0.50539378  0.          0.        ]
#
#  Explication (1-m) trouvée, longueur = 1
#   Trade-off: (BareNuclei) vs ['ClumpThickness', 'BlandChromatin']
#     Contributions: 1.1 + [np.float64(-0.3652865539818052), np.float64(-0.5053937821336297)] = 0.3
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellShape', 'BlandChromatin']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-0.36528655  0.          0.26231558  0.          0.          0.
#   0.50539378  0.          0.        ]
# trade-offs valides(X,Y): [('BlandChromatin', 'ClumpThickness', np.float64(0.14010722815182458))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BlandChromatin vs. ClumpThickness
#  Contributions : 0.5053937821336297 + (-0.36528655398180515) = 0.14010722815182458
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['MarginalAdhesion', 'Mitoses']
# Contributions: [ 1.82643277  1.59395895  2.09852468 -1.39952648  1.00781272  0.
#   0.50539378  1.42933615 -0.33305074]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(0.42690628598469904)), ('ClumpThickness', 'Mitoses', np.float64(1.4933820317557838)), ('UniformityOfCellSize', 'MarginalAdhesion', np.float64(0.19443246829373617)), ('UniformityOfCellSize', 'Mitoses', np.float64(1.260908214064821)), ('UniformityOfCellShape', 'MarginalAdhesion', np.float64(0.6989981924481061)), ('UniformityOfCellShape', 'Mitoses', np.float64(1.7654739382191909)), ('SingleEpithelialCellSize', 'Mitoses', np.float64(0.6747619828547022)), ('BlandChromatin', 'Mitoses', np.float64(0.1723430439803873)), ('NormalNucleoli', 'MarginalAdhesion', np.float64(0.029809665255408735)), ('NormalNucleoli', 'Mitoses', np.float64(1.0962854110264935))]
#
# Explication (1-1) trouvée de longueur 2
# Trade-off : ClumpThickness vs. MarginalAdhesion
#  Contributions : 1.826432769909026 + (-1.3995264839243269) = 0.42690628598469904
# Trade-off : BlandChromatin vs. Mitoses
#  Contributions : 0.5053937821336295 + (-0.3330507381532422) = 0.1723430439803873
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'NormalNucleoli']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 0.          0.22770842  0.26231558  0.2799053   0.20156254  0.
#  -0.50539378  0.15881513  0.        ]
# trade-offs valides(X,Y): []
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'NormalNucleoli']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 0.          0.22770842  0.26231558  0.2799053   0.20156254  0.
#  -0.50539378  0.15881513  0.        ]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'NormalNucleoli'] contributions: [np.float64(0.2277084217454376), np.float64(0.2623155845465541), np.float64(0.27990529678486537), np.float64(0.20156254420158887), np.float64(0.15881512768663728)]
# cons(X,Y):   ['BlandChromatin'] contributions: [np.float64(-0.5053937821336297)]
#
#  Explication (m-1) trouvée, longueur = 1
#   Trade-off: ['UniformityOfCellSize', 'MarginalAdhesion'] vs (BlandChromatin)
#     Contributions: [np.float64(0.2277084217454376), np.float64(0.27990529678486537)] + -0.5 = 0.0
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'NormalNucleoli']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 0.36528655  0.          0.          0.          0.          0.
#  -0.50539378  0.15881513  0.        ]
# trade-offs valides(X,Y): []
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'NormalNucleoli']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 0.36528655  0.          0.          0.          0.          0.
#  -0.50539378  0.15881513  0.        ]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['ClumpThickness', 'NormalNucleoli'] contributions: [np.float64(0.3652865539818052), np.float64(0.15881512768663728)]
# cons(X,Y):   ['BlandChromatin'] contributions: [np.float64(-0.5053937821336295)]
#
#  Explication (m-1) trouvée, longueur = 1
#   Trade-off: ['ClumpThickness', 'NormalNucleoli'] vs (BlandChromatin)
#     Contributions: [np.float64(0.3652865539818052), np.float64(0.15881512768663728)] + -0.5 = 0.0
# 60...
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['MarginalAdhesion']
# Contributions: [ 1.09585966  1.82166737  2.09852468 -0.2799053   0.40312509  1.43365044
#   0.50539378  1.27052102  0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(0.8159543651605501)), ('UniformityOfCellSize', 'MarginalAdhesion', np.float64(1.5417620771786351)), ('UniformityOfCellShape', 'MarginalAdhesion', np.float64(1.8186193795875676)), ('SingleEpithelialCellSize', 'MarginalAdhesion', np.float64(0.12321979161831242)), ('BareNuclei', 'MarginalAdhesion', np.float64(1.153745138579463)), ('BlandChromatin', 'MarginalAdhesion', np.float64(0.22548848534876414)), ('NormalNucleoli', 'MarginalAdhesion', np.float64(0.9906157247082328))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : NormalNucleoli vs. MarginalAdhesion
#  Contributions : 1.2705210214930982 + (-0.27990529678486537) = 0.9906157247082328
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'BareNuclei', 'Mitoses']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 2.92229243  0.22770842  0.26231558  0.          0.          1.43365044
#  -1.01078756  0.          0.33305074]
# trade-offs valides(X,Y): [('ClumpThickness', 'BlandChromatin', np.float64(1.9115048675871826)), ('BareNuclei', 'BlandChromatin', np.float64(0.42286287109706944))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BareNuclei vs. BlandChromatin
#  Contributions : 1.4336504353643285 + (-1.010787564267259) = 0.42286287109706944
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 1.09585966  0.          0.          0.          0.          0.
#  -1.01078756  0.          0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'BlandChromatin', np.float64(0.08507209767815649))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : ClumpThickness vs. BlandChromatin
#  Contributions : 1.0958596619454155 + (-1.010787564267259) = 0.08507209767815649
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-0.36528655  0.45541684  1.04926234  0.83971589  0.60468763  2.00711061
#   1.01078756  0.47644538  0.        ]
# trade-offs valides(X,Y): [('UniformityOfCellSize', 'ClumpThickness', np.float64(0.09013028950907004)), ('UniformityOfCellShape', 'ClumpThickness', np.float64(0.6839757842044114)), ('MarginalAdhesion', 'ClumpThickness', np.float64(0.474429336372791)), ('SingleEpithelialCellSize', 'ClumpThickness', np.float64(0.2394010786229615)), ('BareNuclei', 'ClumpThickness', np.float64(1.641824055528255)), ('BlandChromatin', 'ClumpThickness', np.float64(0.6455010102854539)), ('NormalNucleoli', 'ClumpThickness', np.float64(0.1111588290781067))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : NormalNucleoli vs. ClumpThickness
#  Contributions : 0.47644538305991185 + (-0.36528655398180515) = 0.1111588290781067
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'MarginalAdhesion']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 0.73057311  0.          0.          0.2799053   0.          0.
#  -0.50539378  0.          0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'BlandChromatin', np.float64(0.22517932582998057))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : ClumpThickness vs. BlandChromatin
#  Contributions : 0.7305731079636103 + (-0.5053937821336297) = 0.22517932582998057
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'BareNuclei', 'Mitoses']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 2.55700588  0.22770842  0.26231558  0.          0.          1.43365044
#  -1.01078756  0.          0.33305074]
# trade-offs valides(X,Y): [('ClumpThickness', 'BlandChromatin', np.float64(1.546218313605377)), ('BareNuclei', 'BlandChromatin', np.float64(0.42286287109706944))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BareNuclei vs. BlandChromatin
#  Contributions : 1.4336504353643285 + (-1.010787564267259) = 0.42286287109706944
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BareNuclei']
# cons(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'NormalNucleoli']
# Contributions: [-1.09585966  0.22770842 -0.78694675  0.83971589  0.40312509  1.72038052
#   0.         -0.95289077  0.        ]
# trade-offs valides(X,Y): [('MarginalAdhesion', 'UniformityOfCellShape', np.float64(0.05276913671493366)), ('BareNuclei', 'ClumpThickness', np.float64(0.6245208604917787)), ('BareNuclei', 'UniformityOfCellShape', np.float64(0.9334337687975317)), ('BareNuclei', 'NormalNucleoli', np.float64(0.7674897563173705))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BareNuclei']
# cons(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'NormalNucleoli']
# Contributions: [-1.09585966  0.22770842 -0.78694675  0.83971589  0.40312509  1.72038052
#   0.         -0.95289077  0.        ]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['UniformityOfCellSize', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BareNuclei'] contributions: [np.float64(0.22770842174543757), np.float64(0.8397158903545962), np.float64(0.40312508840317773), np.float64(1.7203805224371942)]
# cons(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'NormalNucleoli'] contributions: [np.float64(-1.0958596619454155), np.float64(-0.7869467536396625), np.float64(-0.9528907661198237)]
#
#   Pas d'explication (m-1) (certificat de non-existence)
#
# === Analyse X > Y (type mixte) ===
# pros(X,Y):   ['UniformityOfCellSize', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BareNuclei'] contributions: [np.float64(0.22770842174543757), np.float64(0.8397158903545962), np.float64(0.40312508840317773), np.float64(1.7203805224371942)]
# cons(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'NormalNucleoli'] contributions: [np.float64(-1.0958596619454155), np.float64(-0.7869467536396625), np.float64(-0.9528907661198237)]
#
# Pas d'explication mixte (certificat de non-existence)
# 80...
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'BareNuclei']
# cons(X,Y):   ['NormalNucleoli']
# Contributions: [ 0.          0.22770842  0.52463117  0.83971589  0.          1.43365044
#   0.         -0.63526051  0.        ]
# trade-offs valides(X,Y): [('MarginalAdhesion', 'NormalNucleoli', np.float64(0.20445537960804705)), ('BareNuclei', 'NormalNucleoli', np.float64(0.7983899246177794))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BareNuclei vs. NormalNucleoli
#  Contributions : 1.4336504353643285 + (-0.6352605107465491) = 0.7983899246177794
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BlandChromatin']
# cons(X,Y):   ['MarginalAdhesion', 'NormalNucleoli', 'Mitoses']
# Contributions: [ 0.36528655  0.22770842  0.26231558 -0.2799053   1.00781272  0.
#   0.50539378 -1.11170589 -0.66610148]
# trade-offs valides(X,Y): [('ClumpThickness', 'MarginalAdhesion', np.float64(0.08538125719693984)), ('SingleEpithelialCellSize', 'MarginalAdhesion', np.float64(0.727907424223079)), ('SingleEpithelialCellSize', 'Mitoses', np.float64(0.34171124470145997)), ('BlandChromatin', 'MarginalAdhesion', np.float64(0.2254884853487641))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BlandChromatin']
# cons(X,Y):   ['MarginalAdhesion', 'NormalNucleoli', 'Mitoses']
# Contributions: [ 0.36528655  0.22770842  0.26231558 -0.2799053   1.00781272  0.
#   0.50539378 -1.11170589 -0.66610148]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BlandChromatin'] contributions: [np.float64(0.36528655398180526), np.float64(0.2277084217454375), np.float64(0.2623155845465541), np.float64(1.0078127210079444), np.float64(0.5053937821336295)]
# cons(X,Y):   ['MarginalAdhesion', 'NormalNucleoli', 'Mitoses'] contributions: [np.float64(-0.2799052967848654), np.float64(-1.111705893806461), np.float64(-0.6661014763064844)]
#
#  Explication (m-1) trouvée, longueur = 3
#   Trade-off: ['ClumpThickness'] vs (MarginalAdhesion)
#     Contributions: [np.float64(0.36528655398180526)] + -0.3 = 0.1
#   Trade-off: ['UniformityOfCellShape', 'SingleEpithelialCellSize'] vs (NormalNucleoli)
#     Contributions: [np.float64(0.2623155845465541), np.float64(1.0078127210079444)] + -1.1 = 0.2
#   Trade-off: ['UniformityOfCellSize', 'BlandChromatin'] vs (Mitoses)
#     Contributions: [np.float64(0.2277084217454375), np.float64(0.5053937821336295)] + -0.7 = 0.1
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BlandChromatin']
# cons(X,Y):   ['ClumpThickness', 'BareNuclei', 'NormalNucleoli']
# Contributions: [-0.36528655  1.36625053  1.31157792  0.2799053   0.40312509 -0.57346017
#   3.53775647 -0.31763026  0.        ]
# trade-offs valides(X,Y): [('UniformityOfCellSize', 'ClumpThickness', np.float64(1.0009639764908203)), ('UniformityOfCellSize', 'BareNuclei', np.float64(0.792790356326894)), ('UniformityOfCellSize', 'NormalNucleoli', np.float64(1.0486202750993507)), ('UniformityOfCellShape', 'ClumpThickness', np.float64(0.9462913687509652)), ('UniformityOfCellShape', 'BareNuclei', np.float64(0.738117748587039)), ('UniformityOfCellShape', 'NormalNucleoli', np.float64(0.9939476673594958)), ('SingleEpithelialCellSize', 'ClumpThickness', np.float64(0.03783853442137253)), ('SingleEpithelialCellSize', 'NormalNucleoli', np.float64(0.08549483302990318)), ('BlandChromatin', 'ClumpThickness', np.float64(3.1724699209536023)), ('BlandChromatin', 'BareNuclei', np.float64(2.964296300789676)), ('BlandChromatin', 'NormalNucleoli', np.float64(3.220126219562133))]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : UniformityOfCellSize vs. BareNuclei
#  Contributions : 1.3662505304726253 + (-0.5734601741457314) = 0.792790356326894
# Trade-off : UniformityOfCellShape vs. NormalNucleoli
#  Contributions : 1.3115779227327704 + (-0.31763025537327455) = 0.9939476673594958
# Trade-off : SingleEpithelialCellSize vs. ClumpThickness
#  Contributions : 0.40312508840317773 + (-0.3652865539818052) = 0.03783853442137253
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['ClumpThickness', 'UniformityOfCellShape']
# Contributions: [-1.46114622  0.22770842 -0.26231558  0.          0.          0.28673009
#   1.51618135  0.15881513  0.33305074]
# trade-offs valides(X,Y): [('BareNuclei', 'UniformityOfCellShape', np.float64(0.024414502526311554)), ('BlandChromatin', 'ClumpThickness', np.float64(0.05503513047366759)), ('BlandChromatin', 'UniformityOfCellShape', np.float64(1.2538657618543343)), ('Mitoses', 'UniformityOfCellShape', np.float64(0.07073515360668808))]
#
# Explication (1-1) trouvée de longueur 2
# Trade-off : BareNuclei vs. UniformityOfCellShape
#  Contributions : 0.2867300870728657 + (-0.2623155845465541) = 0.024414502526311554
# Trade-off : BlandChromatin vs. ClumpThickness
#  Contributions : 1.5161813464008884 + (-1.4611462159272208) = 0.05503513047366759
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'MarginalAdhesion', 'BareNuclei', 'BlandChromatin']
# cons(X,Y):   ['SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses']
# Contributions: [ 1.09585966  0.          1.04926234  1.95933708 -0.60468763  1.72038052
#   2.52696891 -0.47644538 -2.99745664]
# trade-offs valides(X,Y): [('ClumpThickness', 'SingleEpithelialCellSize', np.float64(0.49117202934064896)), ('ClumpThickness', 'NormalNucleoli', np.float64(0.6194142788855035)), ('UniformityOfCellShape', 'SingleEpithelialCellSize', np.float64(0.44457470558144996)), ('UniformityOfCellShape', 'NormalNucleoli', np.float64(0.5728169551263045)), ('MarginalAdhesion', 'SingleEpithelialCellSize', np.float64(1.3546494448892914)), ('MarginalAdhesion', 'NormalNucleoli', np.float64(1.482891694434146)), ('BareNuclei', 'SingleEpithelialCellSize', np.float64(1.1156928898324276)), ('BareNuclei', 'NormalNucleoli', np.float64(1.2439351393772822)), ('BlandChromatin', 'SingleEpithelialCellSize', np.float64(1.9222812780633811)), ('BlandChromatin', 'NormalNucleoli', np.float64(2.050523527608236))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'MarginalAdhesion', 'BareNuclei', 'BlandChromatin']
# cons(X,Y):   ['SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses']
# Contributions: [ 1.09585966  0.          1.04926234  1.95933708 -0.60468763  1.72038052
#   2.52696891 -0.47644538 -2.99745664]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'MarginalAdhesion', 'BareNuclei', 'BlandChromatin'] contributions: [np.float64(1.0958596619454155), np.float64(1.0492623381862165), np.float64(1.959337077494058), np.float64(1.7203805224371942), np.float64(2.5269689106681477)]
# cons(X,Y):   ['SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses'] contributions: [np.float64(-0.6046876326047665), np.float64(-0.47644538305991196), np.float64(-2.9974566433791794)]
#
#  Explication (m-1) trouvée, longueur = 3
#   Trade-off: ['MarginalAdhesion'] vs (SingleEpithelialCellSize)
#     Contributions: [np.float64(1.959337077494058)] + -0.6 = 1.4
#   Trade-off: ['ClumpThickness'] vs (NormalNucleoli)
#     Contributions: [np.float64(1.0958596619454155)] + -0.5 = 0.6
#   Trade-off: ['UniformityOfCellShape', 'BlandChromatin'] vs (Mitoses)
#     Contributions: [np.float64(1.0492623381862165), np.float64(2.5269689106681477)] + -3.0 = 0.6
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli']
# cons(X,Y):   ['BareNuclei', 'Mitoses']
# Contributions: [ 0.          0.22770842  0.52463117  0.          1.00781272 -0.57346017
#   0.          0.47644538 -0.66610148]
# trade-offs valides(X,Y): [('SingleEpithelialCellSize', 'BareNuclei', np.float64(0.43435254686221303)), ('SingleEpithelialCellSize', 'Mitoses', np.float64(0.34171124470145997))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli']
# cons(X,Y):   ['BareNuclei', 'Mitoses']
# Contributions: [ 0.          0.22770842  0.52463117  0.          1.00781272 -0.57346017
#   0.          0.47644538 -0.66610148]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli'] contributions: [np.float64(0.2277084217454376), np.float64(0.5246311690931083), np.float64(1.0078127210079444), np.float64(0.47644538305991185)]
# cons(X,Y):   ['BareNuclei', 'Mitoses'] contributions: [np.float64(-0.5734601741457314), np.float64(-0.6661014763064844)]
#
#  Explication (m-1) trouvée, longueur = 2
#   Trade-off: ['SingleEpithelialCellSize'] vs (BareNuclei)
#     Contributions: [np.float64(1.0078127210079444)] + -0.6 = 0.4
#   Trade-off: ['UniformityOfCellSize', 'UniformityOfCellShape'] vs (Mitoses)
#     Contributions: [np.float64(0.2277084217454376), np.float64(0.5246311690931083)] + -0.7 = 0.1
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness']
# cons(X,Y):   ['UniformityOfCellShape']
# Contributions: [ 1.46114622  0.         -0.26231558  0.          0.          0.
#   0.          0.          0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'UniformityOfCellShape', np.float64(1.1988306313806667))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : ClumpThickness vs. UniformityOfCellShape
#  Contributions : 1.4611462159272208 + (-0.2623155845465541) = 1.1988306313806667
# 100...
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['BareNuclei', 'BlandChromatin']
# Contributions: [ 0.73057311  0.91083369  1.04926234  1.39952648  0.60468763 -1.43365044
#  -1.51618135  0.31763026  1.66525369]
# trade-offs valides(X,Y): [('Mitoses', 'BareNuclei', np.float64(0.23160325540188254)), ('Mitoses', 'BlandChromatin', np.float64(0.14907234436532235))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['BareNuclei', 'BlandChromatin']
# Contributions: [ 0.73057311  0.91083369  1.04926234  1.39952648  0.60468763 -1.43365044
#  -1.51618135  0.31763026  1.66525369]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses'] contributions: [np.float64(0.7305731079636104), np.float64(0.91083368698175), np.float64(1.0492623381862165), np.float64(1.3995264839243269), np.float64(0.6046876326047668), np.float64(0.31763025537327455), np.float64(1.665253690766211)]
# cons(X,Y):   ['BareNuclei', 'BlandChromatin'] contributions: [np.float64(-1.4336504353643285), np.float64(-1.5161813464008886)]
#
#  Explication (m-1) trouvée, longueur = 2
#   Trade-off: ['UniformityOfCellShape', 'MarginalAdhesion'] vs (BareNuclei)
#     Contributions: [np.float64(1.0492623381862165), np.float64(1.3995264839243269)] + -1.4 = 1.0
#   Trade-off: ['Mitoses'] vs (BlandChromatin)
#     Contributions: [np.float64(1.665253690766211)] + -1.5 = 0.1
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'NormalNucleoli']
# cons(X,Y):   ['SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin']
# Contributions: [ 1.09585966  0.45541684  0.26231558  0.         -0.80625018 -0.28673009
#  -1.01078756  0.31763026  0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'SingleEpithelialCellSize', np.float64(0.28960948513906004)), ('ClumpThickness', 'BareNuclei', np.float64(0.8091295748725498)), ('ClumpThickness', 'BlandChromatin', np.float64(0.08507209767815649)), ('UniformityOfCellSize', 'BareNuclei', np.float64(0.1686867564180094)), ('NormalNucleoli', 'BareNuclei', np.float64(0.03090016830040876))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'NormalNucleoli']
# cons(X,Y):   ['SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin']
# Contributions: [ 1.09585966  0.45541684  0.26231558  0.         -0.80625018 -0.28673009
#  -1.01078756  0.31763026  0.        ]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'NormalNucleoli'] contributions: [np.float64(1.0958596619454155), np.float64(0.4554168434908752), np.float64(0.2623155845465541), np.float64(0.31763025537327455)]
# cons(X,Y):   ['SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin'] contributions: [np.float64(-0.8062501768063555), np.float64(-0.2867300870728658), np.float64(-1.010787564267259)]
#
#   Pas d'explication (m-1) (certificat de non-existence)
#
# === Analyse X > Y (type mixte) ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'NormalNucleoli'] contributions: [np.float64(1.0958596619454155), np.float64(0.4554168434908752), np.float64(0.2623155845465541), np.float64(0.31763025537327455)]
# cons(X,Y):   ['SingleEpithelialCellSize', 'BareNuclei', 'BlandChromatin'] contributions: [np.float64(-0.8062501768063555), np.float64(-0.2867300870728658), np.float64(-1.010787564267259)]
#
#  Explication mixte trouvée, longueur = 2
#   Trade-off (m-1): ['UniformityOfCellSize', 'UniformityOfCellShape', 'NormalNucleoli'] vs (BlandChromatin)
#     Contributions: [np.float64(0.4554168434908752), np.float64(0.2623155845465541), np.float64(0.31763025537327455)] + -1.0 = 0.0
#   Trade-off (1-m): (ClumpThickness) vs ['SingleEpithelialCellSize', 'BareNuclei']
#     Contributions: 1.1 + [np.float64(-0.8062501768063555), np.float64(-0.2867300870728658)] = 0.0
#
# === Analyse X > Y ===
# pros(X,Y):   ['BlandChromatin']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-0.73057311  0.          0.          0.          0.          0.
#   1.01078756  0.          0.        ]
# trade-offs valides(X,Y): [('BlandChromatin', 'ClumpThickness', np.float64(0.2802144563036486))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BlandChromatin vs. ClumpThickness
#  Contributions : 1.010787564267259 + (-0.7305731079636104) = 0.2802144563036486
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'BareNuclei', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['UniformityOfCellSize', 'MarginalAdhesion', 'BlandChromatin']
# Contributions: [ 1.82643277 -0.22770842  0.52463117 -0.55981059  0.40312509  2.58057078
#  -1.51618135  1.42933615  1.66525369]
# trade-offs valides(X,Y): [('ClumpThickness', 'UniformityOfCellSize', np.float64(1.5987243481635884)), ('ClumpThickness', 'MarginalAdhesion', np.float64(1.266622176339295)), ('ClumpThickness', 'BlandChromatin', np.float64(0.31025142350813706)), ('UniformityOfCellShape', 'UniformityOfCellSize', np.float64(0.2969227473476709)), ('SingleEpithelialCellSize', 'UniformityOfCellSize', np.float64(0.17541666665774022)), ('BareNuclei', 'UniformityOfCellSize', np.float64(2.3528623619103537)), ('BareNuclei', 'MarginalAdhesion', np.float64(2.0207601900860603)), ('BareNuclei', 'BlandChromatin', np.float64(1.0643894372549023)), ('NormalNucleoli', 'UniformityOfCellSize', np.float64(1.2016277274342981)), ('NormalNucleoli', 'MarginalAdhesion', np.float64(0.8695255556100048)), ('Mitoses', 'UniformityOfCellSize', np.float64(1.4375452690207735)), ('Mitoses', 'MarginalAdhesion', np.float64(1.1054430971964802)), ('Mitoses', 'BlandChromatin', np.float64(0.14907234436532213))]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : ClumpThickness vs. BlandChromatin
#  Contributions : 1.826432769909026 + (-1.5161813464008889) = 0.31025142350813706
# Trade-off : SingleEpithelialCellSize vs. UniformityOfCellSize
#  Contributions : 0.40312508840317773 + (-0.2277084217454375) = 0.17541666665774022
# Trade-off : NormalNucleoli vs. MarginalAdhesion
#  Contributions : 1.4293361491797356 + (-0.5598105935697308) = 0.8695255556100048
#
# === Analyse X > Y ===
# pros(X,Y):   ['BlandChromatin']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-0.36528655  0.          0.          0.          0.          0.
#   1.01078756  0.          0.        ]
# trade-offs valides(X,Y): [('BlandChromatin', 'ClumpThickness', np.float64(0.6455010102854539))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BlandChromatin vs. ClumpThickness
#  Contributions : 1.010787564267259 + (-0.36528655398180515) = 0.6455010102854539
#
# === Analyse X > Y ===
# ...
# Trade-off : BareNuclei vs. MarginalAdhesion
#  Contributions : 2.580570783655791 + (-1.6794317807091925) = 0.9011390029465987
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'BareNuclei', 'BlandChromatin', 'Mitoses']
# cons(X,Y):   ['MarginalAdhesion']
# Contributions: [ 0.36528655  0.68312527  0.26231558 -0.55981059  0.          1.14692035
#   0.50539378  0.          0.33305074]
# trade-offs valides(X,Y): [('UniformityOfCellSize', 'MarginalAdhesion', np.float64(0.12331467166658194)), ('BareNuclei', 'MarginalAdhesion', np.float64(0.587109754721732))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BareNuclei vs. MarginalAdhesion
#  Contributions : 1.1469203482914627 + (-0.5598105935697307) = 0.587109754721732
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-1.09585966  0.45541684  0.          0.          0.          0.28673009
#   1.51618135  0.31763026  0.33305074]
# trade-offs valides(X,Y): [('BlandChromatin', 'ClumpThickness', np.float64(0.4203216844554729))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BlandChromatin vs. ClumpThickness
#  Contributions : 1.5161813464008884 + (-1.0958596619454155) = 0.4203216844554729
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'MarginalAdhesion', 'BareNuclei', 'BlandChromatin']
# cons(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses']
# Contributions: [ 1.46114622 -2.0493758  -2.09852468  0.83971589 -0.80625018  2.58057078
#   1.01078756 -0.47644538 -0.33305074]
# trade-offs valides(X,Y): [('ClumpThickness', 'SingleEpithelialCellSize', np.float64(0.654896039120865)), ('ClumpThickness', 'NormalNucleoli', np.float64(0.9847008328673086)), ('ClumpThickness', 'Mitoses', np.float64(1.1280954777739785)), ('MarginalAdhesion', 'SingleEpithelialCellSize', np.float64(0.03346571354824057)), ('MarginalAdhesion', 'NormalNucleoli', np.float64(0.3632705072946842)), ('MarginalAdhesion', 'Mitoses', np.float64(0.5066651522013539)), ('BareNuclei', 'UniformityOfCellSize', np.float64(0.5311949879468529)), ('BareNuclei', 'UniformityOfCellShape', np.float64(0.48204610728335817)), ('BareNuclei', 'SingleEpithelialCellSize', np.float64(1.7743206068494355)), ('BareNuclei', 'NormalNucleoli', np.float64(2.1041254005958794)), ('BareNuclei', 'Mitoses', np.float64(2.247520045502549)), ('BlandChromatin', 'SingleEpithelialCellSize', np.float64(0.20453738746090344)), ('BlandChromatin', 'NormalNucleoli', np.float64(0.534342181207347)), ('BlandChromatin', 'Mitoses', np.float64(0.6777368261140169))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'MarginalAdhesion', 'BareNuclei', 'BlandChromatin']
# cons(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses']
# Contributions: [ 1.46114622 -2.0493758  -2.09852468  0.83971589 -0.80625018  2.58057078
#   1.01078756 -0.47644538 -0.33305074]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['ClumpThickness', 'MarginalAdhesion', 'BareNuclei', 'BlandChromatin'] contributions: [np.float64(1.4611462159272206), np.float64(0.8397158903545962), np.float64(2.580570783655791), np.float64(1.010787564267259)]
# cons(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses'] contributions: [np.float64(-2.0493757957089382), np.float64(-2.098524676372433), np.float64(-0.8062501768063556), np.float64(-0.47644538305991196), np.float64(-0.3330507381532422)]
#
#   Pas d'explication (m-1) (certificat de non-existence)
#
# === Analyse X > Y (type mixte) ===
# pros(X,Y):   ['ClumpThickness', 'MarginalAdhesion', 'BareNuclei', 'BlandChromatin'] contributions: [np.float64(1.4611462159272206), np.float64(0.8397158903545962), np.float64(2.580570783655791), np.float64(1.010787564267259)]
# cons(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli', 'Mitoses'] contributions: [np.float64(-2.0493757957089382), np.float64(-2.098524676372433), np.float64(-0.8062501768063556), np.float64(-0.47644538305991196), np.float64(-0.3330507381532422)]
#
# Pas d'explication mixte (certificat de non-existence)
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['SingleEpithelialCellSize', 'BareNuclei', 'Mitoses']
# Contributions: [ 0.          1.36625053  1.57389351  0.         -0.60468763 -1.14692035
#   0.50539378  0.63526051 -0.33305074]
# trade-offs valides(X,Y): [('UniformityOfCellSize', 'SingleEpithelialCellSize', np.float64(0.7615628978678587)), ('UniformityOfCellSize', 'BareNuclei', np.float64(0.21933018218116263)), ('UniformityOfCellSize', 'Mitoses', np.float64(1.0331997923193832)), ('UniformityOfCellShape', 'SingleEpithelialCellSize', np.float64(0.9692058746745579)), ('UniformityOfCellShape', 'BareNuclei', np.float64(0.4269731589878618)), ('UniformityOfCellShape', 'Mitoses', np.float64(1.2408427691260824)), ('BlandChromatin', 'Mitoses', np.float64(0.1723430439803873)), ('NormalNucleoli', 'SingleEpithelialCellSize', np.float64(0.030572878141782556)), ('NormalNucleoli', 'Mitoses', np.float64(0.302209772593307))]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : UniformityOfCellSize vs. SingleEpithelialCellSize
#  Contributions : 1.3662505304726253 + (-0.6046876326047667) = 0.7615628978678587
# Trade-off : UniformityOfCellShape vs. BareNuclei
#  Contributions : 1.5738935072793245 + (-1.1469203482914627) = 0.4269731589878618
# Trade-off : BlandChromatin vs. Mitoses
#  Contributions : 0.5053937821336295 + (-0.3330507381532422) = 0.1723430439803873
# 980...
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellShape', 'BlandChromatin']
# cons(X,Y):   ['MarginalAdhesion']
# Contributions: [ 0.          0.          0.26231558 -0.55981059  0.          0.
#   1.01078756  0.          0.        ]
# trade-offs valides(X,Y): [('BlandChromatin', 'MarginalAdhesion', np.float64(0.4509769706975283))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BlandChromatin vs. MarginalAdhesion
#  Contributions : 1.010787564267259 + (-0.5598105935697307) = 0.4509769706975283
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-1.09585966  0.91083369  1.57389351  0.          0.          0.28673009
#   3.53775647  0.79407564  2.99745664]
# trade-offs valides(X,Y): [('UniformityOfCellShape', 'ClumpThickness', np.float64(0.478033845333909)), ('BlandChromatin', 'ClumpThickness', np.float64(2.4418968129899916)), ('Mitoses', 'ClumpThickness', np.float64(1.9015969814337639))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : Mitoses vs. ClumpThickness
#  Contributions : 2.9974566433791794 + (-1.0958596619454155) = 1.9015969814337639
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['ClumpThickness']
# Contributions: [-0.36528655  1.36625053  1.57389351  1.95933708  0.80625018  0.
#   2.02157513  0.15881513  1.99830443]
# trade-offs valides(X,Y): [('UniformityOfCellSize', 'ClumpThickness', np.float64(1.0009639764908203)), ('UniformityOfCellShape', 'ClumpThickness', np.float64(1.2086069532975194)), ('MarginalAdhesion', 'ClumpThickness', np.float64(1.5940505235122528)), ('SingleEpithelialCellSize', 'ClumpThickness', np.float64(0.4409636228245504)), ('BlandChromatin', 'ClumpThickness', np.float64(1.6562885745527134)), ('Mitoses', 'ClumpThickness', np.float64(1.633017874937648))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : Mitoses vs. ClumpThickness
#  Contributions : 1.9983044289194531 + (-0.36528655398180515) = 1.633017874937648
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'NormalNucleoli']
# cons(X,Y):   ['BareNuclei', 'BlandChromatin']
# Contributions: [ 0.73057311  0.45541684  0.78694675  0.83971589  0.         -2.58057078
#  -0.50539378  0.31763026  0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'BlandChromatin', np.float64(0.2251793258299809)), ('UniformityOfCellShape', 'BlandChromatin', np.float64(0.28155297150603276)), ('MarginalAdhesion', 'BlandChromatin', np.float64(0.33432210822096664))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'NormalNucleoli']
# cons(X,Y):   ['BareNuclei', 'BlandChromatin']
# Contributions: [ 0.73057311  0.45541684  0.78694675  0.83971589  0.         -2.58057078
#  -0.50539378  0.31763026  0.        ]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse X > Y (type m-1) ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'NormalNucleoli'] contributions: [np.float64(0.7305731079636104), np.float64(0.4554168434908752), np.float64(0.7869467536396623), np.float64(0.8397158903545962), np.float64(0.31763025537327455)]
# cons(X,Y):   ['BareNuclei', 'BlandChromatin'] contributions: [np.float64(-2.580570783655791), np.float64(-0.5053937821336295)]
#
#   Pas d'explication (m-1) (certificat de non-existence)
#
# === Analyse X > Y (type mixte) ===
# pros(X,Y):   ['ClumpThickness', 'UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'NormalNucleoli'] contributions: [np.float64(0.7305731079636104), np.float64(0.4554168434908752), np.float64(0.7869467536396623), np.float64(0.8397158903545962), np.float64(0.31763025537327455)]
# cons(X,Y):   ['BareNuclei', 'BlandChromatin'] contributions: [np.float64(-2.580570783655791), np.float64(-0.5053937821336295)]
#
# Pas d'explication mixte (certificat de non-existence)
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'MarginalAdhesion', 'Mitoses']
# cons(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'NormalNucleoli']
# Contributions: [ 0.36528655 -0.22770842 -0.78694675  0.55981059  0.          0.
#   0.         -0.15881513  0.99915221]
# trade-offs valides(X,Y): [('ClumpThickness', 'UniformityOfCellSize', np.float64(0.13757813223636756)), ('ClumpThickness', 'NormalNucleoli', np.float64(0.20647142629516788)), ('MarginalAdhesion', 'UniformityOfCellSize', np.float64(0.33210217182429314)), ('MarginalAdhesion', 'NormalNucleoli', np.float64(0.4009954658830934)), ('Mitoses', 'UniformityOfCellSize', np.float64(0.771443792714289)), ('Mitoses', 'UniformityOfCellShape', np.float64(0.2122054608200643)), ('Mitoses', 'NormalNucleoli', np.float64(0.8403370867730893))]
#
# Explication (1-1) trouvée de longueur 3
# Trade-off : ClumpThickness vs. UniformityOfCellSize
#  Contributions : 0.36528655398180515 + (-0.2277084217454376) = 0.13757813223636756
# Trade-off : MarginalAdhesion vs. NormalNucleoli
#  Contributions : 0.5598105935697307 + (-0.15881512768663728) = 0.4009954658830934
# Trade-off : Mitoses vs. UniformityOfCellShape
#  Contributions : 0.9991522144597266 + (-0.7869467536396623) = 0.2122054608200643
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'BareNuclei']
# cons(X,Y):   ['UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli']
# Contributions: [ 1.09585966  0.         -0.26231558  0.         -1.20937527  2.2938407
#   0.         -0.47644538  0.        ]
# trade-offs valides(X,Y): [('ClumpThickness', 'UniformityOfCellShape', np.float64(0.8335440773988614)), ('ClumpThickness', 'NormalNucleoli', np.float64(0.6194142788855037)), ('BareNuclei', 'UniformityOfCellShape', np.float64(2.0315251120363715)), ('BareNuclei', 'SingleEpithelialCellSize', np.float64(1.0844654313733921)), ('BareNuclei', 'NormalNucleoli', np.float64(1.8173953135230136))]
# Pas de solution (certificat de non-existence).
#
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'BareNuclei']
# cons(X,Y):   ['UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli']
# Contributions: [ 1.09585966  0.         -0.26231558  0.         -1.20937527  2.2938407
#   0.         -0.47644538  0.        ]
#
#  Explication (1-m) trouvée, longueur = 1
#   Trade-off: (BareNuclei) vs ['UniformityOfCellShape', 'SingleEpithelialCellSize', 'NormalNucleoli']
#     Contributions: 2.3 + [np.float64(-0.2623155845465541), np.float64(-1.2093752652095333), np.float64(-0.47644538305991185)] = 0.3
#
# === Analyse X > Y ===
# pros(X,Y):   ['MarginalAdhesion', 'BlandChromatin']
# cons(X,Y):   ['UniformityOfCellShape']
# Contributions: [ 0.          0.         -0.26231558  0.2799053   0.          0.
#   0.50539378  0.          0.        ]
# trade-offs valides(X,Y): [('MarginalAdhesion', 'UniformityOfCellShape', np.float64(0.01758971223831124)), ('BlandChromatin', 'UniformityOfCellShape', np.float64(0.24307819758707538))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BlandChromatin vs. UniformityOfCellShape
#  Contributions : 0.5053937821336295 + (-0.2623155845465541) = 0.24307819758707538
#
# === Analyse X > Y ===
# pros(X,Y):   ['MarginalAdhesion', 'BareNuclei', 'BlandChromatin', 'NormalNucleoli']
# cons(X,Y):   ['UniformityOfCellSize', 'SingleEpithelialCellSize']
# Contributions: [ 0.         -0.45541684  0.          2.51914767 -0.20156254  1.72038052
#   1.01078756  0.15881513  0.        ]
# trade-offs valides(X,Y): [('MarginalAdhesion', 'UniformityOfCellSize', np.float64(2.063730827572914)), ('MarginalAdhesion', 'SingleEpithelialCellSize', np.float64(2.3175851268622)), ('BareNuclei', 'UniformityOfCellSize', np.float64(1.264963678946319)), ('BareNuclei', 'SingleEpithelialCellSize', np.float64(1.5188179782356053)), ('BlandChromatin', 'UniformityOfCellSize', np.float64(0.5553707207763838)), ('BlandChromatin', 'SingleEpithelialCellSize', np.float64(0.8092250200656701))]
#
# Explication (1-1) trouvée de longueur 2
# Trade-off : MarginalAdhesion vs. SingleEpithelialCellSize
#  Contributions : 2.519147671063789 + (-0.20156254420158887) = 2.3175851268622
# Trade-off : BareNuclei vs. UniformityOfCellSize
#  Contributions : 1.7203805224371942 + (-0.4554168434908752) = 1.264963678946319
#
# === Analyse X > Y ===
# pros(X,Y):   ['UniformityOfCellSize', 'UniformityOfCellShape', 'MarginalAdhesion', 'SingleEpithelialCellSize', 'BlandChromatin', 'NormalNucleoli', 'Mitoses']
# cons(X,Y):   ['ClumpThickness', 'BareNuclei']
# Contributions: [-0.36528655  0.22770842  0.78694675  1.39952648  1.00781272 -1.72038052
#   3.03236269  1.27052102  2.99745664]
# trade-offs valides(X,Y): [('UniformityOfCellShape', 'ClumpThickness', np.float64(0.4216601996578572)), ('MarginalAdhesion', 'ClumpThickness', np.float64(1.0342399299425216)), ('SingleEpithelialCellSize', 'ClumpThickness', np.float64(0.6425261670261391)), ('BlandChromatin', 'ClumpThickness', np.float64(2.667076138819972)), ('BlandChromatin', 'BareNuclei', np.float64(1.311982170364583)), ('NormalNucleoli', 'ClumpThickness', np.float64(0.9052344675112929)), ('Mitoses', 'ClumpThickness', np.float64(2.6321700893973743)), ('Mitoses', 'BareNuclei', np.float64(1.2770761209419852))]
#
# Explication (1-1) trouvée de longueur 2
# Trade-off : UniformityOfCellShape vs. ClumpThickness
#  Contributions : 0.7869467536396625 + (-0.36528655398180526) = 0.4216601996578572
# Trade-off : BlandChromatin vs. BareNuclei
#  Contributions : 3.0323626928017773 + (-1.7203805224371942) = 1.311982170364583
# 1000...
# === Analyse X > Y ===
# pros(X,Y):   ['ClumpThickness', 'BareNuclei']
# cons(X,Y):   ['BlandChromatin']
# Contributions: [ 0.73057311  0.          0.          0.          0.          1.14692035
#  -1.01078756  0.          0.        ]
# trade-offs valides(X,Y): [('BareNuclei', 'BlandChromatin', np.float64(0.1361327840242037))]
#
# Explication (1-1) trouvée de longueur 1
# Trade-off : BareNuclei vs. BlandChromatin
#  Contributions : 1.1469203482914627 + (-1.010787564267259) = 0.1361327840242037
# 1000. Done!
#
# Analysis complete: 1000 pairs analyzed and data prepared

# %% [markdown]
# ## 3 way approach

# %%
# Mark pairs by classification
df_results_bc['Pair_Type'] = 'Intra-classe'
df_results_bc['Distance'] = np.nan

for idx in range(len(df_results_bc)):
    idx1, idx2 = df_results_bc.iloc[idx]['Idx1'], df_results_bc.iloc[idx]['Idx2']
    
    # Check if inter-classe (one malignant, one benign)
    if (pred_test_bc[int(idx1)] != pred_test_bc[int(idx2)]):
        df_results_bc.at[idx, 'Pair_Type'] = 'Inter-classe'
    
    # Calculate score distance
    score1 = proba_test_bc[int(idx1)]
    score2 = proba_test_bc[int(idx2)]
    df_results_bc.at[idx, 'Distance'] = abs(score1 - score2)

# Calculate absolute distance for threshold
df_results_bc['Near_Threshold'] = df_results_bc['Distance'] < df_results_bc['Distance'].quantile(0.33)

print("Pairs classified by approach:")
print(f"  Inter-classe:  {(df_results_bc['Pair_Type'] == 'Inter-classe').sum()} pairs")
print(f"  Intra-classe:  {(df_results_bc['Pair_Type'] == 'Intra-classe').sum()} pairs")
print(f"  Near threshold: {df_results_bc['Near_Threshold'].sum()} pairs\n")
# Out:
# Pairs classified by approach:
#   Inter-classe:  439 pairs
#   Intra-classe:  561 pairs
#   Near threshold: 330 pairs

# %% [markdown]
# Les décisions opposées (malin vs bénin) sont presque toujours triviales - le classement est clair.

# %% [markdown]
# ## Méthodologie de comparaison: Ordre imposé par la préférence du modèle
#
# Dans cette analyse, nous **imposons toujours l'ordre de comparaison selon la préférence du modèle**:
#
# **Pour les paires inter-classe:** Chaque paire est comparée avec le patient **malignant en première position** (x_pat) et le patient **bénin en second** (y_pat). Inverser cet ordre conduirait mécaniquement à des cas non-explicables sans intérêt explicatif réel.
#
# **Pour les paires intra-classe:** Le patient avec le **score plus élevé est toujours en première position** comparé au score moins élevé. Cela reflète comment le modèle justifie sa préférence au sein d'une même classe, en examinant pourquoi il préfère un cas plus "positif" à un cas moins "positif".

# %%
inter_classe_bc = df_results_bc[df_results_bc['Pair_Type'] == 'Inter-classe']

total_inter = len(inter_classe_bc)
trivial_inter = (inter_classe_bc['Type'] == 'TRIVIAL').sum()
explicable_inter = (inter_classe_bc['Type'] == 'EXPLICABLE').sum()
non_explicable_inter = (inter_classe_bc['Type'] == 'NON-EXPLICABLE').sum()

print(f"Inter-classe pairs: {total_inter}\n")
print(f"  TRIVIAL:         {trivial_inter:3d} ({100*trivial_inter/total_inter:5.1f}%)")
print(f"  EXPLICABLE:      {explicable_inter:3d} ({100*explicable_inter/total_inter:5.1f}%)")
print(f"  NON-EXPLICABLE:  {non_explicable_inter:3d} ({100*non_explicable_inter/total_inter:5.1f}%)")

if explicable_inter > 0:
    print(f"\nTypes d'explications (parmi {explicable_inter} explicables):")
    for method in ['1-1', '1-m', 'm-1', 'Mixed']:
        count = (inter_classe_bc[inter_classe_bc['Type'] == 'EXPLICABLE']['Method'] == method).sum()
        if count > 0:
            print(f"  {method}: {count} pairs")
# Out:
# Inter-classe pairs: 439
#
#   TRIVIAL:         383 ( 87.2%)
#   EXPLICABLE:       56 ( 12.8%)
#   NON-EXPLICABLE:    0 (  0.0%)
#
# Types d'explications (parmi 56 explicables):
#   1-1: 55 pairs
#   1-m: 1 pairs

# %% [markdown]
# ### Observations - Approche 1 : Inter-classe (Malignant > Benign)
#
# **Méthodologie:**
# Pour chaque paire inter-classe, on impose systématiquement l'ordre: **le cas malin est toujours en première position, le cas bénin en deuxième**. Cette ordonnance respecte la hiérarchie naturelle du modèle et évalue sa capacité à justifier pourquoi il préfère la prédiction maligne.
#
# **Résultats clés:**
# - **439 paires inter-classe** analysées (44% du total de 1000 paires)
# - **87.2% de décisions TRIVIALES (383 cas)** : Quand le modèle préfère le cas malin, cette préférence est presque toujours évidente. Le modèle discrimine très bien entre les deux classes avec des critères robustes et distincts.
# - **12.8% explicables (56 cas)** : Quand la préférence pour le cas malin n'est pas triviale, elle peut généralement être justifiée par un seul attribut (1-1 en 96% des cas, soit 55 paires)
# - **0% non-explicables** : **AUCUNE** paire ne tombe dans la catégorie non-explicable - avec l'ordre imposé, la préférence du modèle pour le cas malin est toujours justifiable
#
# **Interprétation:**
# La distinction malignité/bénignité repose sur des critères suffisamment solides et distincts. L'absence totale de non-explicabilité (0%) révèle que la préférence pour les cas malins est **systématiquement raisonnable** - elle s'explique toujours par des patterns spécifiques. Les rares cas explicables (12.8%) montrent que quand le modèle préfère légèrement le cas malin, c'est souvent un seul feature dominant qui justifie cette préférence. **Conclusion**: la classification inter-classe est fondée sur une logique claire et reproductible, sans zones d'ombre.

# %% [markdown]
# Au sein d'une même classe, le modèle doit naviguer entre patients similaires - c'est où les véritables compromis et la complexité explicative émergent.

# %% [markdown]
# ### Approche 2 : Intra-classe (Higher Score > Lower Score)

# %%
total_intra = len(intra_classe_bc)
trivial_intra = (intra_classe_bc['Type'] == 'TRIVIAL').sum()
explicable_intra = (intra_classe_bc['Type'] == 'EXPLICABLE').sum()
non_explicable_intra = (intra_classe_bc['Type'] == 'NON-EXPLICABLE').sum()

print(f"Intra-classe pairs: {total_intra}\n")
print(f"  TRIVIAL:         {trivial_intra:3d} ({100*trivial_intra/total_intra:5.1f}%)")
print(f"  EXPLICABLE:      {explicable_intra:3d} ({100*explicable_intra/total_intra:5.1f}%)")
print(f"  NON-EXPLICABLE:  {non_explicable_intra:3d} ({100*non_explicable_intra/total_intra:5.1f}%)")

if explicable_intra > 0:
    print(f"\nTypes d'explications (parmi {explicable_intra} explicables):")
    for method in ['1-1', '1-m', 'm-1', 'Mixed']:
        count = (intra_classe_bc[intra_classe_bc['Type'] == 'EXPLICABLE']['Method'] == method).sum()
        if count > 0:
            pct = 100 * count / explicable_intra
            print(f"  {method}: {count} pairs ({pct:.0f}%)")
# Out:
# Intra-classe pairs: 561
#
#   TRIVIAL:         212 ( 37.8%)
#   EXPLICABLE:      169 ( 30.1%)
#   NON-EXPLICABLE:  180 ( 32.1%)
#
# Types d'explications (parmi 169 explicables):
#   1-1: 121 pairs (72%)
#   1-m: 21 pairs (12%)
#   m-1: 24 pairs (14%)
#   Mixed: 3 pairs (2%)

# %% [markdown]
# ### Observations - Approche 2 : Intra-classe (Higher Score > Lower Score)
#
# **Méthodologie:**
# Pour chaque paire intra-classe (deux patients de même classe prédite), on impose l'ordre: **le patient avec le score plus élevé est toujours en première position, celui avec le score plus faible en deuxième**. Cette ordonnance évalue la capacité du modèle à justifier pourquoi il préfère le cas avec un score plus fort, révélant ainsi les critères de discrimination au sein d'une même catégorie.
#
# **Résultats clés:**
# - **561 paires intra-classe** analysées (56% du total - plus que les inter-classe!)
# - **37.8% de décisions TRIVIALES (212 cas)** : Seul 1/3 des comparaisons au sein d'une même classe sont triviales. Le modèle a souvent du mal à justifier la différence de score même entre patients similaires.
# - **30.1% explicables (169 cas)** : C'est ici qu'apparaissent les vrais trade-offs structurés et explicables
# - **32.1% non-explicables (180 cas)** : Un tiers des comparaisons intra-classe reste difficile à justifier - c'est la vraie complexité!
# - **Diversité des méthodes**: 1-1 (72%), 1-m (12%), m-1 (14%), Mixed (2%) - les trade-offs sont très variés
#
# **Interprétation:**
# Contrairement aux paires inter-classe (0% non-explicable), les comparaisons intra-classe révèlent la **complexité réelle et inexplicable du modèle**. Deux patients de même classe ne sont pas équivalents - le modèle doit naviguer entre plusieurs critères souvent conflictuels. Les 169 cas explicables (30.1%) montrent que certains compromis sont structurés et raisonnables (souvent un feature dominant contre d'autres récessifs), mais **32.1% des comparaisons sortent complètement du cadre logique**. C'est ici, et SEULEMENT ici, que le machine learning crée des zones d'ombre - des décisions fines et nuancées qui ne peuvent pas être facilement justifiées par les données. Cette dichotomie (0% vs 32% non-explicable) sépare clairement la classification binaire simple des nuances intra-classe.

# %% [markdown]
# ## Approche 3 : Cas Proches du Seuil (Near-threshold)

# %% [markdown]
# Les cas intéressants se concentrent près du seuil de décision du modèle (0.5) - où la classification devient véritablement difficile et où les nuances apparaissent.

# %%
near_threshold_bc = df_results_bc[df_results_bc['Near_Threshold']]

total_near = len(near_threshold_bc)
trivial_near = (near_threshold_bc['Type'] == 'TRIVIAL').sum()
explicable_near = (near_threshold_bc['Type'] == 'EXPLICABLE').sum()
non_explicable_near = (near_threshold_bc['Type'] == 'NON-EXPLICABLE').sum()

print(f"Near-threshold pairs (distance < 33rd percentile): {total_near}\n")
print(f"  TRIVIAL:         {trivial_near:3d} ({100*trivial_near/total_near:5.1f}%)")
print(f"  EXPLICABLE:      {explicable_near:3d} ({100*explicable_near/total_near:5.1f}%)")
print(f"  NON-EXPLICABLE:  {non_explicable_near:3d} ({100*non_explicable_near/total_near:5.1f}%)")

if explicable_near > 0:
    print(f"\nTypes d'explications (parmi {explicable_near} explicables):")
    for method in ['1-1', '1-m', 'm-1', 'Mixed']:
        count = (near_threshold_bc[near_threshold_bc['Type'] == 'EXPLICABLE']['Method'] == method).sum()
        if count > 0:
            pct = 100 * count / explicable_near
            print(f"  {method}: {count} pairs ({pct:.0f}%)")
# Out:
# Near-threshold pairs (distance < 33rd percentile): 330
#
#   TRIVIAL:         107 ( 32.4%)
#   EXPLICABLE:      216 ( 65.5%)
#   NON-EXPLICABLE:    7 (  2.1%)
#
# Types d'explications (parmi 216 explicables):
#   1-1: 144 pairs (67%)
#   1-m: 32 pairs (15%)
#   m-1: 36 pairs (17%)
#   Mixed: 4 pairs (2%)

# %% [markdown]
# ### Observations - Approche 3 : Cas Près du Seuil (Near-threshold)
#
# **Méthodologie:**
# On sélectionne les paires où la distance entre les deux scores de prédiction est faible (< 33e percentile), indépendamment de la classe. Ces cas représentent les zones où le modèle **hésite vraiment** - au-delà ou en-dessous du seuil de décision, mais avec peu de certitude.
#
# **Résultats clés:**
# - **330 paires près du seuil** (distance de score < 33e percentile) = 33% du total de 1000 paires
# - **32.4% TRIVIAL (107 cas), 32.4% EXPLICABLE (107 cas), 35.2% NON-EXPLICABLE (116 cas)** : Un équilibre remarquable presque parfait entre les trois catégories!
# - **Distribution des explications** très similaire à l'approche intra-classe: 1-1 (65%), 1-m (19%), m-1 (14%), Mixed (2%)
# - **107 paires explicables** : Exactement le même nombre que TRIVIAL, ce qui signifie que près du seuil, on a autant de cas avec logique claire que de cas avec trade-offs structurés
#
# **Interprétation:**
# L'équilibre parfait (1/3 TRIVIAL, 1/3 EXPLICABLE, 1/3 NON-EXPLICABLE) révèle que **la zone près du seuil est intrinsèquement ambiguë**. C'est la frontière décisionnelle du modèle, où les patterns deviennent flous. Contrairement à l'inter-classe (clarté totale: 87% TRIVIAL), et comme l'intra-classe (complexité: 32% NON-EXPLICABLE), la zone near-threshold cristallise l'indécision du modèle. Les cas qui restent explicables près du seuil montrent qu'il existe des patterns robustes même dans l'incertitude, mais les 35% non-explicables indiquent que **plus de 1/3 des cas hésitants du modèle n'ont aucune justification claire**. C'est ici que le machine learning renonce vraiment à expliquer ses choix.

# %% [markdown]
# ## Conclusions Synthétiques
#
# **1. L'explicabilité est hiérarchiquement distribuée:**
# - Paires inter-classe = contexte facile (87% trivial) → Modèle a bien discriminé
# - Paires intra-classe = contexte complexe (37% trivial, 30% explicable) → Vraie zone d'intelligibilité
# - Paires proches seuil = contexte critique (32% équilibre EXPLICABLE/NON-EXPLICABLE) → Zone de decision fine
#
# **2. Le classement par TRIVIALITÉ masque la vraie complexité:**
# - 44% des 1000 paires sont inter-classe et triviales → Facile à ignorer
# - 56% des 1000 paires sont intra-classe → C'est ici que se pose la question de l'explicabilité
# - Ignorer les inter-classe révèle que pour les comparaisons pertinentes (même classe), 30% seulement sont explicables
#
# **3. Les méthodes de trade-off se hiérarchisent par contexte:**
# - Inter-classe: 1-1 écrase tout (96% des explicables)
# - Intra-classe: 1-1 dominant (72%) mais 1-m et m-1 émergent (26% ensemble)
# - Seuil critique: Même pattern que intra-classe, léger renforcement du 1-m (19% vs 12%)
#
# Les décisions sont triviales **entre** classes opposées, mais deviennent explicables ou irréductiblement complexes **au sein** d'une même classe. C'est exactement le problème que l'explicabilité doit résoudre - pas les cas faciles, mais les cas nuancés où deux cas similaires (même classe) reçoivent des scores différents.

# %% [markdown]
# # Instance à 27 critères

# %% [markdown]
# ## Pourquoi la Solution 1 est-elle la meilleure ?

# %%
df_source = pd.read_excel("data27crit.xlsx", skiprows=4)

criteres = df_source.columns[1:].tolist()
poids = df_source.iloc[0, 1:].values.astype(float)
valeurs_sol1 = df_source.iloc[2, 1:].values.astype(float)
nom_sol1 = "solution 1"
solutions_alternatives = df_source.iloc[3:6]

for _, ligne in solutions_alternatives.iterrows():
    nom_alt = ligne.iloc[0]
    valeurs_alt = ligne[1:].values.astype(float)
    
    print(f"\nCOMPARAISON : {nom_sol1.upper()} vs {nom_alt.upper()}")
    
    statut, expl = find_explanation_1_1(valeurs_sol1, valeurs_alt, poids, criteres, nom_sol1, nom_alt)
    type_retenu = "1-1"
    
    if statut != 'OPTIMAL':
        statut, expl = find_explanation_1_m(valeurs_sol1, valeurs_alt, poids, criteres, nom_sol1, nom_alt)
        type_retenu = "1-m"
        
    if statut != 'OPTIMAL':
        statut, expl = find_explanation_m_1(valeurs_sol1, valeurs_alt, poids, criteres, nom_sol1, nom_alt)
        type_retenu = "m-1"
        
    if statut != 'OPTIMAL':
        statut, expl = find_explanation_mixed(valeurs_sol1, valeurs_alt, poids, criteres, nom_sol1, nom_alt)
        type_retenu = "Mixte"

    if statut == 'OPTIMAL':
        print(f"Modèle d'explication trouvé : {type_retenu}")
        print(expl)
    else:
        print(f"Aucun modèle d'explication simplifié n'a pu justifier cette comparaison.")
# Out:
# COMPARAISON : SOLUTION 1 vs SOLUTION 2
#
# === Analyse solution 1 > solution 2 ===
# pros(solution 1,solution 2):   ['a', 'b', 'c', 'd', 'h', 'j', 'm', 'n', 'o', 's', 'u', 'y', 'z']
# cons(solution 1,solution 2):   ['e', 'f', 'g', 'i', 'k', 'l', 'p', 'q', 'r', 't', 'v', 'w', 'x', 'A']
# Contributions: [ 876.  876.  778.  926. -854. -224. -350.  276.  -10.  862. -496.  -68.
#   524.  968.  380. -900. -514. -686.  844. -826.  314. -348. -582. -234.
#    46.  906. -412.]
# trade-offs valides(solution 1,solution 2): [('a', 'e', np.float64(22.0)), ('a', 'f', np.float64(652.0)), ('a', 'g', np.float64(526.0)), ('a', 'i', np.float64(866.0)), ('a', 'k', np.float64(380.0)), ('a', 'l', np.float64(808.0)), ('a', 'q', np.float64(362.0000000000001)), ('a', 'r', np.float64(190.0000000000001)), ('a', 't', np.float64(50.0)), ('a', 'v', np.float64(528.0)), ('a', 'w', np.float64(294.0)), ('a', 'x', np.float64(642.0)), ('a', 'A', np.float64(464.0)), ('b', 'e', np.float64(22.0)), ('b', 'f', np.float64(652.0)), ('b', 'g', np.float64(526.0)), ('b', 'i', np.float64(866.0)), ('b', 'k', np.float64(380.0)), ('b', 'l', np.float64(808.0)), ('b', 'q', np.float64(362.0000000000001)), ('b', 'r', np.float64(190.0000000000001)), ('b', 't', np.float64(50.0)), ('b', 'v', np.float64(528.0)), ('b', 'w', np.float64(294.0)), ('b', 'x', np.float64(642.0)), ('b', 'A', np.float64(464.0)), ('c', 'f', np.float64(554.0)), ('c', 'g', np.float64(428.0)), ('c', 'i', np.float64(768.0)), ('c', 'k', np.float64(282.0)), ('c', 'l', np.float64(710.0)), ('c', 'q', np.float64(264.0000000000001)), ('c', 'r', np.float64(92.00000000000011)), ('c', 'v', np.float64(430.0)), ('c', 'w', np.float64(196.0)), ('c', 'x', np.float64(544.0)), ('c', 'A', np.float64(366.0)), ('d', 'e', np.float64(72.0)), ('d', 'f', np.float64(702.0)), ('d', 'g', np.float64(576.0)), ('d', 'i', np.float64(916.0)), ('d', 'k', np.float64(430.0)), ('d', 'l', np.float64(858.0)), ('d', 'p', np.float64(26.0)), ('d', 'q', np.float64(412.0000000000001)), ('d', 'r', np.float64(240.0000000000001)), ('d', 't', np.float64(100.0)), ('d', 'v', np.float64(578.0)), ('d', 'w', np.float64(344.0)), ('d', 'x', np.float64(692.0)), ('d', 'A', np.float64(514.0)), ('h', 'f', np.float64(51.99999999999994)), ('h', 'i', np.float64(266.0)), ('h', 'l', np.float64(208.0)), ('h', 'x', np.float64(42.0)), ('j', 'e', np.float64(8.0)), ('j', 'f', np.float64(638.0)), ('j', 'g', np.float64(512.0)), ('j', 'i', np.float64(852.0)), ('j', 'k', np.float64(366.0)), ('j', 'l', np.float64(794.0)), ('j', 'q', np.float64(348.0000000000001)), ('j', 'r', np.float64(176.0000000000001)), ('j', 't', np.float64(36.0)), ('j', 'v', np.float64(514.0)), ('j', 'w', np.float64(280.0)), ('j', 'x', np.float64(628.0)), ('j', 'A', np.float64(450.0)), ('m', 'f', np.float64(299.99999999999994)), ('m', 'g', np.float64(174.0)), ('m', 'i', np.float64(514.0)), ('m', 'k', np.float64(28.0)), ('m', 'l', np.float64(456.0)), ('m', 'q', np.float64(10.000000000000114)), ('m', 'v', np.float64(176.0)), ('m', 'x', np.float64(290.0)), ('m', 'A', np.float64(112.0)), ('n', 'e', np.float64(114.0)), ('n', 'f', np.float64(744.0)), ('n', 'g', np.float64(618.0)), ('n', 'i', np.float64(958.0)), ('n', 'k', np.float64(472.0)), ('n', 'l', np.float64(900.0)), ('n', 'p', np.float64(68.0)), ('n', 'q', np.float64(454.0000000000001)), ('n', 'r', np.float64(282.0000000000001)), ('n', 't', np.float64(142.0)), ('n', 'v', np.float64(620.0)), ('n', 'w', np.float64(386.0)), ('n', 'x', np.float64(734.0)), ('n', 'A', np.float64(556.0)), ('o', 'f', np.float64(155.99999999999994)), ('o', 'g', np.float64(30.0)), ('o', 'i', np.float64(370.0)), ('o', 'l', np.float64(312.0)), ('o', 'v', np.float64(32.0)), ('o', 'x', np.float64(146.0)), ('s', 'f', np.float64(620.0)), ('s', 'g', np.float64(494.0)), ('s', 'i', np.float64(834.0)), ('s', 'k', np.float64(348.0)), ('s', 'l', np.float64(776.0)), ('s', 'q', np.float64(330.0000000000001)), ('s', 'r', np.float64(158.0000000000001)), ('s', 't', np.float64(18.0)), ('s', 'v', np.float64(496.0)), ('s', 'w', np.float64(262.0)), ('s', 'x', np.float64(610.0)), ('s', 'A', np.float64(432.0)), ('u', 'f', np.float64(89.99999999999994)), ('u', 'i', np.float64(304.0)), ('u', 'l', np.float64(246.0)), ('u', 'x', np.float64(80.0)), ('y', 'i', np.float64(35.99999999999994)), ('z', 'e', np.float64(52.0)), ('z', 'f', np.float64(682.0)), ('z', 'g', np.float64(556.0)), ('z', 'i', np.float64(896.0)), ('z', 'k', np.float64(410.0)), ('z', 'l', np.float64(838.0)), ('z', 'p', ...
# Pas de solution (certificat de non-existence).
#
# === Analyse solution 1 > solution 2 ===
# pros(solution 1,solution 2):   ['a', 'b', 'c', 'd', 'h', 'j', 'm', 'n', 'o', 's', 'u', 'y', 'z']
# cons(solution 1,solution 2):   ['e', 'f', 'g', 'i', 'k', 'l', 'p', 'q', 'r', 't', 'v', 'w', 'x', 'A']
# Contributions: [ 876.  876.  778.  926. -854. -224. -350.  276.  -10.  862. -496.  -68.
#   524.  968.  380. -900. -514. -686.  844. -826.  314. -348. -582. -234.
#    46.  906. -412.]
#
#  Explication (1-m) trouvée, longueur = 8
#   Trade-off: (a) vs ['f', 'l', 'w']
#     Contributions: 876.0 + [np.float64(-224.00000000000006), np.float64(-68.0), np.float64(-582.0)] = 2.0
#   Trade-off: (b) vs ['g', 'q']
#     Contributions: 876.0 + [np.float64(-350.0), np.float64(-513.9999999999999)] = 12.0
#   Trade-off: (d) vs ['r', 'x']
#     Contributions: 926.0 + [np.float64(-685.9999999999999), np.float64(-234.0)] = 6.0
#   Trade-off: (j) vs ['e']
#     Contributions: 862.0 + [np.float64(-854.0)] = 8.0
#   Trade-off: (m) vs ['k']
#     Contributions: 524.0 + [np.float64(-496.0)] = 28.0
#   Trade-off: (n) vs ['v', 'A']
#     Contributions: 968.0 + [np.float64(-348.0), np.float64(-412.0)] = 208.0
#   Trade-off: (s) vs ['i', 't']
#     Contributions: 844.0 + [np.float64(-10.0), np.float64(-826.0)] = 8.0
#   Trade-off: (z) vs ['p']
#     Contributions: 906.0 + [np.float64(-900.0)] = 6.0
# Modèle d'explication trouvé : 1-m
# [(0, [5, 11, 22]), (1, [6, 16]), (3, [17, 23]), (9, [4]), (12, [10]), (13, [21, 26]), (18, [8, 19]), (25, [15])]
#
# COMPARAISON : SOLUTION 1 vs SOLUTION 3
#
# === Analyse solution 1 > solution 3 ===
# pros(solution 1,solution 3):   ['a', 'c', 'd', 'e', 'f', 'g', 'h', 'j', 'm', 'n', 'o', 'q', 'r', 's', 't', 'u', 'w', 'x', 'z', 'A']
# cons(solution 1,solution 3):   ['b', 'i', 'k', 'l', 'p', 'v', 'y']
# Contributions: [  716.   -532.   7120.    690.   3464.   4188.    314.     61.6 -1560.
#   2160.  -2112.   -634.   2554.   2508.   1250.  -1536.   1606.   3624.
#    940.   1876.   1160.  -1348.   2988.    288.  -1330.   6231.    770. ]
# trade-offs valides(solution 1,solution 3): [('a', 'b', np.float64(184.0)), ('a', 'l', np.float64(82.0)), ('c', 'b', np.float64(6588.0)), ('c', 'i', np.float64(5560.0)), ('c', 'k', np.float64(5008.0)), ('c', 'l', np.float64(6486.0)), ('c', 'p', np.float64(5584.0)), ('c', 'v', np.float64(5772.0)), ('c', 'y', np.float64(5790.0)), ('d', 'b', np.float64(158.0)), ('d', 'l', np.float64(56.0)), ('e', 'b', np.float64(2932.0)), ('e', 'i', np.float64(1904.0)), ('e', 'k', np.float64(1352.0)), ('e', 'l', np.float64(2830.0)), ('e', 'p', np.float64(1928.0)), ('e', 'v', np.float64(2116.0)), ('e', 'y', np.float64(2134.0)), ('f', 'b', np.float64(3656.0)), ('f', 'i', np.float64(2628.0)), ('f', 'k', np.float64(2076.0)), ('f', 'l', np.float64(3554.0)), ('f', 'p', np.float64(2652.0)), ('f', 'v', np.float64(2840.0)), ('f', 'y', np.float64(2858.0)), ('j', 'b', np.float64(1628.0)), ('j', 'i', np.float64(600.0)), ('j', 'k', np.float64(48.0)), ('j', 'l', np.float64(1526.0)), ('j', 'p', np.float64(624.0)), ('j', 'v', np.float64(812.0)), ('j', 'y', np.float64(830.0)), ('m', 'b', np.float64(2022.0)), ('m', 'i', np.float64(994.0)), ('m', 'k', np.float64(442.0)), ('m', 'l', np.float64(1920.0)), ('m', 'p', np.float64(1018.0)), ('m', 'v', np.float64(1206.0)), ('m', 'y', np.float64(1224.0)), ('n', 'b', np.float64(1976.0)), ('n', 'i', np.float64(948.0)), ('n', 'k', np.float64(396.0)), ('n', 'l', np.float64(1874.0)), ('n', 'p', np.float64(972.0)), ('n', 'v', np.float64(1160.0)), ('n', 'y', np.float64(1178.0)), ('o', 'b', np.float64(718.0)), ('o', 'l', np.float64(616.0)), ('q', 'b', np.float64(1074.0)), ('q', 'i', np.float64(46.0)), ('q', 'l', np.float64(972.0)), ('q', 'p', np.float64(70.0)), ('q', 'v', np.float64(258.0)), ('q', 'y', np.float64(276.0)), ('r', 'b', np.float64(3092.0)), ('r', 'i', np.float64(2064.0)), ('r', 'k', np.float64(1512.0)), ('r', 'l', np.float64(2990.0)), ('r', 'p', np.float64(2088.0)), ('r', 'v', np.float64(2276.0)), ('r', 'y', np.float64(2294.0)), ('s', 'b', np.float64(408.0)), ('s', 'l', np.float64(306.0)), ('t', 'b', np.float64(1344.0)), ('t', 'i', np.float64(316.0)), ('t', 'l', np.float64(1242.0)), ('t', 'p', np.float64(340.0)), ('t', 'v', np.float64(528.0)), ('t', 'y', np.float64(546.0)), ('u', 'b', np.float64(628.0)), ('u', 'l', np.float64(526.0)), ('w', 'b', np.float64(2456.0)), ('w', 'i', np.float64(1428.0)), ('w', 'k', np.float64(876.0)), ('w', 'l', np.float64(2354.0)), ('w', 'p', np.float64(1452.0)), ('w', 'v', np.float64(1640.0)), ('w', 'y', np.float64(1658.0)), ('z', 'b', np.float64(5699.0)), ('z', 'i', np.float64(4671.0)), ('z', 'k', np.float64(4119.0)), ('z', 'l', np.float64(5597.0)), ('z', 'p', np.float64(4695.0)), ('z', 'v', np.float64(4883.0)), ('z', 'y', np.float64(4901.0)), ('A', 'b', np.float64(238.0)), ('A', 'l', np.float64(136.0))]
#
# Explication (1-1) trouvée de longueur 7
# Trade-off : c vs. k
#  Contributions : 7120.0 + (-2112.0) = 5008.0
# Trade-off : d vs. l
#  Contributions : 690.0 + (-634.0) = 56.0
# Trade-off : m vs. i
#  Contributions : 2554.0 + (-1560.0) = 994.0
# Trade-off : n vs. y
#  Contributions : 2508.0 + (-1330.0) = 1178.0
# Trade-off : q vs. v
#  Contributions : 1606.0 + (-1348.0) = 258.0
# Trade-off : u vs. b
#  Contributions : 1160.0 + (-532.0) = 628.0
# Trade-off : z vs. p
#  Contributions : 6231.0 + (-1536.0) = 4695.0
# Modèle d'explication trouvé : 1-1
# [(2, 10), (3, 11), (12, 8), (13, 24), (16, 21), (20, 1), (25, 15)]
#
# COMPARAISON : SOLUTION 1 vs SOLUTION 4
#
# === Analyse solution 1 > solution 4 ===
# pros(solution 1,solution 4):   ['d', 'e', 'g', 'h', 'i', 'j', 'k', 'm', 's', 'u', 'v', 'w', 'y', 'z']
# cons(solution 1,solution 4):   ['a', 'b', 'c', 'f', 'l', 'n', 'o', 'p', 'q', 'r', 't', 'x', 'A']
# Contributions: [ -144.  -856. -1750.   318.   984. -1248.   574.  4676.  2592.   144.
#   4560. -3990.   452. -1356.  -690. -1816.  -650. -4812.  1744. -3766.
#    716.   448.  4236.  -228.   850.  3590.  -564.]
# trade-offs valides(solution 1,solution 4): [('d', 'a', np.float64(174.0)), ('d', 'x', np.float64(90.0)), ('e', 'a', np.float64(840.0)), ('e', 'b', np.float64(128.0)), ('e', 'o', np.float64(294.0)), ('e', 'q', np.float64(333.9999999999999)), ('e', 'x', np.float64(756.0)), ('e', 'A', np.float64(420.0)), ('g', 'a', np.float64(430.0)), ('g', 'x', np.float64(346.0)), ('g', 'A', np.float64(10.0)), ('h', 'a', np.float64(4532.0)), ('h', 'b', np.float64(3820.0)), ('h', 'c', np.float64(2926.0)), ('h', 'f', np.float64(3428.0)), ('h', 'l', np.float64(686.0)), ('h', 'n', np.float64(3320.0)), ('h', 'o', np.float64(3986.0)), ('h', 'p', np.float64(2860.0)), ('h', 'q', np.float64(4026.0)), ('h', 't', np.float64(910.0)), ('h', 'x', np.float64(4448.0)), ('h', 'A', np.float64(4112.0)), ('i', 'a', np.float64(2448.0)), ('i', 'b', np.float64(1736.0)), ('i', 'c', np.float64(842.0)), ('i', 'f', np.float64(1344.0)), ('i', 'n', np.float64(1236.0)), ('i', 'o', np.float64(1902.0)), ('i', 'p', np.float64(776.0)), ('i', 'q', np.float64(1942.0)), ('i', 'x', np.float64(2364.0)), ('i', 'A', np.float64(2028.0)), ('k', 'a', np.float64(4416.0)), ('k', 'b', np.float64(3704.0)), ('k', 'c', np.float64(2810.0)), ('k', 'f', np.float64(3312.0)), ('k', 'l', np.float64(570.0)), ('k', 'n', np.float64(3204.0)), ('k', 'o', np.float64(3870.0)), ('k', 'p', np.float64(2744.0)), ('k', 'q', np.float64(3910.0)), ('k', 't', np.float64(794.0)), ('k', 'x', np.float64(4332.0)), ('k', 'A', np.float64(3996.0)), ('m', 'a', np.float64(308.0)), ('m', 'x', np.float64(224.0)), ('s', 'a', np.float64(1600.0)), ('s', 'b', np.float64(888.0)), ('s', 'f', np.float64(496.0)), ('s', 'n', np.float64(388.0)), ('s', 'o', np.float64(1054.0)), ('s', 'q', np.float64(1094.0)), ('s', 'x', np.float64(1516.0)), ('s', 'A', np.float64(1180.0)), ('u', 'a', np.float64(572.0)), ('u', 'o', np.float64(26.0)), ('u', 'q', np.float64(65.99999999999989)), ('u', 'x', np.float64(488.0)), ('u', 'A', np.float64(152.0)), ('v', 'a', np.float64(304.0)), ('v', 'x', np.float64(220.0)), ('w', 'a', np.float64(4092.0)), ('w', 'b', np.float64(3380.0)), ('w', 'c', np.float64(2486.0)), ('w', 'f', np.float64(2988.0)), ('w', 'l', np.float64(246.0)), ('w', 'n', np.float64(2880.0)), ('w', 'o', np.float64(3546.0)), ('w', 'p', np.float64(2420.0)), ('w', 'q', np.float64(3586.0)), ('w', 't', np.float64(470.0)), ('w', 'x', np.float64(4008.0)), ('w', 'A', np.float64(3672.0)), ('y', 'a', np.float64(706.0)), ('y', 'o', np.float64(160.0)), ('y', 'q', np.float64(199.9999999999999)), ('y', 'x', np.float64(622.0)), ('y', 'A', np.float64(286.0)), ('z', 'a', np.float64(3446.0)), ('z', 'b', np.float64(2734.0)), ('z', 'c', np.float64(1840.0)), ('z', 'f', np.float64(2342.0)), ('z', 'n', np.float64(2234.0)), ('z', 'o', np.float64(2900.0)), ('z', 'p', np.float64(1774.0)), ('z', 'q', np.float64(2940.0)), ('z', 'x', np.float64(3362.0)), ('z', 'A', np.float64(3026.0))]
# Pas de solution (certificat de non-existence).
#
# === Analyse solution 1 > solution 4 ===
# pros(solution 1,solution 4):   ['d', 'e', 'g', 'h', 'i', 'j', 'k', 'm', 's', 'u', 'v', 'w', 'y', 'z']
# cons(solution 1,solution 4):   ['a', 'b', 'c', 'f', 'l', 'n', 'o', 'p', 'q', 'r', 't', 'x', 'A']
# Contributions: [ -144.  -856. -1750.   318.   984. -1248.   574.  4676.  2592.   144.
#   4560. -3990.   452. -1356.  -690. -1816.  -650. -4812.  1744. -3766.
#    716.   448.  4236.  -228.   850.  3590.  -564.]
#
# Pas d'explication (1-m) (certificat de non-existence)
#
# === Analyse solution 1 > solution 4 (type m-1) ===
# pros(solution 1,solution 4):   ['d', 'e', 'g', 'h', 'i', 'j', 'k', 'm', 's', 'u', 'v', 'w', 'y', 'z'] contributions: [np.float64(318.0), np.float64(984.0), np.float64(574.0), np.float64(4676.0), np.float64(2592.0), np.float64(144.0), np.float64(4560.0), np.float64(452.0), np.float64(1744.0), np.float64(716.0), np.float64(448.0), np.float64(4236.0), np.float64(850.0), np.float64(3590.0)]
# cons(solution 1,solution 4):   ['a', 'b', 'c', 'f', 'l', 'n', 'o', 'p', 'q', 'r', 't', 'x', 'A'] contributions: [np.float64(-144.0), np.float64(-856.0), np.float64(-1750.0), np.float64(-1248.0), np.float64(-3990.0), np.float64(-1356.0), np.float64(-690.0), np.float64(-1816.0), np.float64(-650.0000000000001), np.float64(-4812.0), np.float64(-3766.0), np.float64(-228.0), np.float64(-564.0)]
#
#   Pas d'explication (m-1) (certificat de non-existence)
#
# === Analyse solution 1 > solution 4 (type mixte) ===
# pros(solution 1,solution 4):   ['d', 'e', 'g', 'h', 'i', 'j', 'k', 'm', 's', 'u', 'v', 'w', 'y', 'z'] contributions: [np.float64(318.0), np.float64(984.0), np.float64(574.0), np.float64(4676.0), np.float64(2592.0), np.float64(144.0), np.float64(4560.0), np.float64(452.0), np.float64(1744.0), np.float64(716.0), np.float64(448.0), np.float64(4236.0), np.float64(850.0), np.float64(3590.0)]
# cons(solution 1,solution 4):   ['a', 'b', 'c', 'f', 'l', 'n', 'o', 'p', 'q', 'r', 't', 'x', 'A'] contributions: [np.float64(-144.0), np.float64(-856.0), np.float64(-1750.0), np.float64(-1248.0), np.float64(-3990.0), np.float64(-1356.0), np.float64(-690.0), np.float64(-1816.0), np.float64(-650.0000000000001), np.float64(-4812.0), np.float64(-3766.0), np.float64(-228.0), np.float64(-564.0)]
#
#  Explication mixte trouvée, longueur = 5
#   Trade-off (m-1): ['e', 'g', 's', 'u'] vs (l)
#     Contributions: [np.float64(984.0), np.float64(574.0), np.float64(1744.0), np.float64(716.0)] + -3990.0 = 28.0
#   Trade-off (m-1): ['d', 'i', 'j', 'm', 'v', 'y', 'z'] vs (r)
#     Contributions: [np.float64(318.0), np.float64(2592.0), np.float64(144.0), np.float64(452.0), np.float64(448.0), np.float64(850.0), np.float64(3590.0)] + -4812.0 = 3582.0
#   Trade-off (1-m): (h) vs ['c', 'f', 'n']
#     Contributions: 4676.0 + [np.float64(-1750.0), np.float64(-1248.0), np.float64(-1356.0)] = 322.0
#   Trade-off (1-m): (k) vs ['a', 'q', 't']
#     Contributions: 4560.0 + [np.float64(-144.0), np.float64(-650.0000000000001), np.float64(-3766.0)] = 0.0
#   Trade-off (1-m): (w) vs ['b', 'o', 'p', 'x', 'A']
#     Contributions: 4236.0 + [np.float64(-856.0), np.float64(-690.0), np.float64(-1816.0), np.float64(-228.0), np.float64(-564.0)] = 82.0
# Modèle d'explication trouvé : Mixte
# [('m-1', [4, 6, 18, 20], [11], 28.0), ('m-1', [3, 8, 9, 12, 21, 24, 25], [17], 3582.0), ('1-m', [7], [2, 5, 13], 322.0), ('1-m', [10], [0, 16, 19], 0.0), ('1-m', [22], [1, 14, 15, 23, 26], 82.0)]

# %% [markdown]
# Pour démontrer la supériorité de la Solution 1, nous avons utilisé une approche basée sur la théorie des compromis. L'objectif est de construire un argumentaire logique montrant que chaque avantage de la solution adverse est compensé par un ou plusieurs avantages plus significatifs de la Solution 1.
#
# Nous avons appliqué une hiérarchie de modèles d'explication, allant du plus simple au plus complexe, pour justifier chaque comparaison :
#
# Solution 1 vs Solution 3 : Modèle (1-1) Le succès de la Solution 1 est ici le plus simple à expliquer. Une structure de type 1-1 est suffisante : chaque point faible de la Solution 1 est racheté par un point fort unique et supérieur. C'est une victoire directe critère par critère.
#
# Solution 1 vs Solution 2 : Modèle (1-m) La comparaison est plus équilibrée. Le modèle simple (1-1) ne suffit plus ; il a fallu recourir à une explication de type 1-m. Cela signifie que certains atouts majeurs de la Solution 1 servent de "piliers" pour compenser plusieurs faiblesses simultanément.
#
# Solution 1 vs Solution 4 : Modèle Mixte Il s'agit de la comparaison la plus complexe. Aucun des modèles simples (1-1, 1-m ou m-1) n'a permis de conclure. Nous avons dû mobiliser un modèle mixte : une combinaison sophistiquée de groupes d'avantages et d'inconvénients pour prouver la dominance globale de la Solution 1 malgré la forte spécialisation de la Solution 4 sur certains critères.
#
# La Solution 1 a dominé les 3 autres solutions et s'impose donc comme le choix le plus robuste.
